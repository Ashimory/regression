# %% [markdown]
# # Team members:
# - Nguyễn Duy Minh (myself)
# - Vũ Trường Giang
# - Vũ Hồng Phúc

# %%
import pandas as pd
import statsmodels.api as sm
import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv(r'./owid-2022-clean.csv')

# %%
# Drop irrelevant fields
print(df.columns.shape)
df.drop(["location", "date", "total_deaths_per_million", "total_cases_per_million", "population", "tests_units"], axis=1, inplace=True)

print(df.columns.shape)
# Out:
# (31,)
# (25,)

# %% [markdown]
#  # 1. Data preparations
#  - NaN/missing values are replaced with the median value of the country's other records.
#  - If all values are NaN/missing/zeros, replace them with the median value of the records from all countries within the same continent
#  - Only replace zero values when the entire column of the country is 0. This is because countries like Vietnam have days where no deaths are recorded, but other days still record a positive number. This is different to countries where no death numbers are recorded. There are cases where zero values may slightly raise some eyebrows, for example Albania recording no new cases in multiple days. However, they might as well be zero because "new_cases_per_million" mean some thing like "new_cases_reported_per_million" for example. Since our target variables are also based on reports, it may be best to simply also respect these reported zero values in other columns.
#  - A much better way to deal with these values (in my opinion) is to group countries by factors like GDP and poverty rate. However, it is more difficult and time consuming to do this since multiple factors need to be considered and the values are numeric instead of categorical. Since we have 6 deadlines this weekend, our team unfortunately had to abandon this approach for lack of time.

# %%
applied_cols = list(df.columns)
df_group_iso = df.groupby(["iso_code"])
df_group_cont = df.groupby(["continent"])

for col_name, col_data in df.iteritems():
    if col_name == "iso_code" or col_name=="continent":
        continue
    # replace nan with country median
    df[col_name] = df_group_iso[col_name].apply(lambda x: x.fillna(x.median()))
    # replace nan with continent median
    df[col_name] = df_group_cont[col_name].apply(lambda x: x.fillna(x.median()))

# Replace zeroes
df_group_cont_med = df_group_cont.median()
for col_name, col_data in df_group_iso:    
    for col in col_data:
        if (col_data[col] == 0).all():
            target = df.loc[df["iso_code"] == col_name]
            df.loc[df["iso_code"] == col_name, col] = target[col].replace(0, df_group_cont_med.at[target["continent"].iloc[0], col])

# %%
indicator_cols = pd.get_dummies(df[ "continent"])
df = pd.concat([df, indicator_cols], axis=1)
df = df.groupby("iso_code").agg("mean")
print(df.columns)
# Out:
#           new_cases_per_million  new_deaths_per_million  \
# iso_code
# AFG                   14.337571                0.100429
# AGO                    1.233429                0.004143
# ALB                  314.859857                2.038857
# AND                 1569.777571                3.693714
# ARE                  204.511000                0.314286
# ...                         ...                     ...
# WSM                    0.713714                0.000000
# YEM                    1.157286                0.075143
# ZAF                   47.509571                2.208143
# ZMB                   17.139429                0.121000
# ZWE                    6.966714                0.227143
#
#           new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# iso_code
# AFG                              0.033000       0.452071        2.200000
# AGO                              0.076429       0.021829       51.714286
# ALB                              0.720714       0.608714        1.642857
# AND                              2.847714       0.735957        1.357143
# ARE                             49.131857       0.004471      224.800000
# ...                                   ...            ...             ...
# WSM                              3.823000       0.134000        7.500000
# YEM                              1.762000       0.239500        4.200000
# ZAF                              0.515143       0.095471       10.500000
# ZMB                              0.196714       0.093686       10.714286
# ZWE                              1.285571       0.007914      146.485714
#
#           people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# iso_code
# AFG                           11.560000                             9.880000
# AGO                           29.470000                            14.380000
# ALB                           43.680000                            40.581429
# AND                           74.710000                            68.790000
# ARE                           67.590000                            93.521429
# ...                                 ...                                  ...
# WSM                           72.000000                            63.000000
# YEM                            1.970000                             1.180000
# ZAF                           32.841429                            27.852857
# ZMB                           16.590000                             8.974286
# ZWE                           28.420000                            21.984286
#
#           total_boosters_per_hundred  stringency_index  population_density  \
# iso_code
# AFG                        24.115000             19.44              54.422
# AGO                         0.895000             70.37              23.890
# ALB                         7.355714             61.11             104.871
# AND                        42.815000             35.19             163.755
# ARE                        44.229286             44.44             112.442
# ...                              ...               ...                 ...
# WSM                        31.930000             62.04              69.413
# YEM                        24.115000             26.85              53.508
# ZAF                         1.080000             41.67              46.754
# ZMB                         0.895000             27.78              22.995
# ZWE                         0.481429             50.00              42.729
#
#           ...  handwashing_facilities  hospital_beds_per_thousand  \
# iso_code  ...
# AFG       ...                 37.7460                        0.50
# AGO       ...                 26.6640                        1.20
# ALB       ...                 97.1640                        2.89
# AND       ...                 97.1640                        4.51
# ARE       ...                 72.7040                        1.20
# ...       ...                     ...                         ...
# WSM       ...                 30.5495                        2.45
# YEM       ...                 49.5420                        0.70
# ZAF       ...                 43.9930                        2.32
# ZMB       ...                 13.9380                        2.00
# ZWE       ...                 36.7910                        1.70
#
#           life_expectancy  human_development_index  Africa  Asia  Europe  \
# iso_code
# AFG                 64.83                    0.511     0.0   1.0     0.0
# AGO                 61.15                    0.581     1.0   0.0     0.0
# ALB                 78.57                    0.795     0.0   0.0     1.0
# AND                 83.73                    0.868     0.0   0.0     1.0
# ARE                 77.97                    0.890     0.0   1.0     0.0
# ...                   ...                      ...     ...   ...     ...
# WSM                 73.32                    0.715     0.0   0.0     0.0
# YEM                 66.12                    0.470     0.0   1.0     0.0
# ZAF                 64.13                    0.709     1.0   0.0     0.0
# ZMB                 63.89                    0.584     1.0   0.0     0.0
# ZWE                 61.49                    0.571     1.0   0.0     0.0
#
#           North America  Oceania  South America
# iso_code
# AFG                 0.0      0.0            0.0
# AGO                 0.0      0.0            0.0
# ALB                 0.0      0.0            0.0
# AND                 0.0      0.0            0.0
# ARE                 0.0      0.0            0.0
# ...                 ...      ...            ...
# WSM                 0.0      1.0            0.0
# YEM                 0.0      0.0            0.0
# ZAF                 0.0      0.0            0.0
# ZMB                 0.0      0.0            0.0
# ZWE                 0.0      0.0            0.0
#
# [189 rows x 29 columns]

# %%
df.to_csv("./data.csv")

# %%
def linear_regression(X: pd.DataFrame, y: pd.DataFrame, ft_in_use, log = False):
    X = X[ft_in_use]

    model = sm.OLS(y, sm.add_constant(X))
    results = model.fit()

    if (log):
        print(results.summary())

    y_pred = results.predict(sm.add_constant(X))
    print(f'MSE: {sum((y - y_pred) ** 2) / len(y)}')
    return results

# %%
df = pd.read_csv('data.csv')

ft_predict = ['new_deaths_per_million', 'new_cases_per_million']
ft_ignore = ['iso_code', 'location', 'date', 'total_deaths', 'total_cases_per_million', 'total_deaths_per_million', 'population', 'tests_units'] # add ignore column names here

features = list(set(df.columns).difference(ft_predict + ft_ignore))

y = df[ft_predict]
X = df[features]

# %%
def new_deaths_per_million(X: pd.DataFrame, y: pd.DataFrame, ft_in_use):
    return linear_regression(X, y['new_deaths_per_million'], ft_in_use, log = True)

# %%
def new_cases_per_million(X: pd.DataFrame, y: pd.DataFrame, ft_in_use):
    return linear_regression(X, y['new_cases_per_million'], ft_in_use, log = True)

# %%
# ordinary linear regression

dth = new_deaths_per_million(X, y, features)
cas = new_cases_per_million(X, y, features)
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.554
# Model:                                OLS   Adj. R-squared:                  0.482
# Method:                     Least Squares   F-statistic:                     7.739
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.56e-17
# Time:                            23:22:39   Log-Likelihood:                -403.13
# No. Observations:                     189   AIC:                             860.3
# Df Residuals:                         162   BIC:                             947.8
# Df Model:                              26
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.5247      3.462     -1.596      0.112     -12.360       1.311
# population_density                     -0.0001      0.000     -0.456      0.649      -0.001       0.000
# hospital_beds_per_thousand             -0.1664      0.114     -1.464      0.145      -0.391       0.058
# people_vaccinated_per_hundred          -0.0099      0.020     -0.503      0.616      -0.049       0.029
# Asia                                   -1.4595      0.772     -1.890      0.061      -2.985       0.066
# male_smokers                           -0.0018      0.019     -0.095      0.925      -0.039       0.035
# people_fully_vaccinated_per_hundred    -0.0159      0.020     -0.812      0.418      -0.055       0.023
# handwashing_facilities                  0.0087      0.014      0.642      0.522      -0.018       0.036
# gdp_per_capita                      -2.879e-05   1.62e-05     -1.780      0.077   -6.07e-05    3.14e-06
# South America                           0.7534      0.851      0.885      0.377      -0.927       2.434
# stringency_index                        0.0009      0.011      0.078      0.938      -0.022       0.023
# new_tests_smoothed_per_thousand        -0.0060      0.017     -0.350      0.727      -0.040       0.028
# female_smokers                          0.1231      0.034      3.664      0.000       0.057       0.189
# total_boosters_per_hundred             -0.0300      0.017     -1.790      0.075      -0.063       0.003
# cardiovasc_death_rate                   0.0019      0.002      0.880      0.380      -0.002       0.006
# Europe                                 -0.6172      1.021     -0.605      0.546      -2.633       1.399
# median_age                              0.1339      0.077      1.731      0.085      -0.019       0.287
# extreme_poverty                         0.0063      0.017      0.360      0.720      -0.028       0.041
# life_expectancy                         0.0131      0.063      0.209      0.834      -0.110       0.137
# tests_per_case                      -4.574e-06   1.61e-05     -0.285      0.776   -3.63e-05    2.71e-05
# human_development_index                 5.6707      4.152      1.366      0.174      -2.528      13.869
# diabetes_prevalence                     0.0547      0.059      0.935      0.351      -0.061       0.170
# positive_rate                          -0.2391      1.549     -0.154      0.878      -3.299       2.820
# aged_70_older                          -0.0406      0.310     -0.131      0.896      -0.652       0.571
# Africa                                 -1.4627      0.841     -1.739      0.084      -3.123       0.198
# aged_65_older                           0.0265      0.204      0.130      0.897      -0.377       0.430
# North America                          -0.2305      0.780     -0.296      0.768      -1.771       1.310
# Oceania                                -2.5081      1.169     -2.145      0.033      -4.817      -0.199
# ==============================================================================
# Omnibus:                       48.903   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.228
# Skew:                           1.129   Prob(JB):                     2.12e-26
# Kurtosis:                       6.148   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.34e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 4.17049691756357
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.580
# Model:                               OLS   Adj. R-squared:                  0.513
# Method:                    Least Squares   F-statistic:                     8.619
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.91e-19
# Time:                           23:22:39   Log-Likelihood:                -1559.2
# No. Observations:                    189   AIC:                             3172.
# Df Residuals:                        162   BIC:                             3260.
# Df Model:                             26
# Covariance Type:               nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                -238.8769   1569.812     -0.152      0.879   -3338.809    2861.055
# population_density                     -0.1097      0.110     -0.994      0.322      -0.328       0.108
# hospital_beds_per_thousand            -78.8003     51.538     -1.529      0.128    -180.573      22.972
# people_vaccinated_per_hundred           1.8164      8.928      0.203      0.839     -15.814      19.447
# Asia                                  205.7032    350.297      0.587      0.558    -486.034     897.440
# male_smokers                           -4.0515      8.531     -0.475      0.635     -20.898      12.795
# people_fully_vaccinated_per_hundred    -1.2438      8.879     -0.140      0.889     -18.778      16.291
# handwashing_facilities                 -2.1947      6.167     -0.356      0.722     -14.373       9.984
# gdp_per_capita                      -7.907e-05      0.007     -0.011      0.991      -0.015       0.014
# South America                        -553.1468    385.947     -1.433      0.154   -1315.283     208.990
# stringency_index                       -0.0190      5.144     -0.004      0.997     -10.178      10.140
# new_tests_smoothed_per_thousand        29.8444      7.748      3.852      0.000      14.545      45.144
# female_smokers                          6.1139     15.235      0.401      0.689     -23.970      36.198
# total_boosters_per_hundred             17.9024      7.607      2.353      0.020       2.881      32.924
# cardiovasc_death_rate                  -0.3739      0.990     -0.378      0.706      -2.328       1.581
# Europe                                266.8218    462.934      0.576      0.565    -647.341    1180.984
# median_age                            -47.5291     35.081     -1.355      0.177    -116.804      21.746
# extreme_poverty                         1.4820      7.928      0.187      0.852     -14.173      17.137
# life_expectancy                       -23.5319     28.353     -0.830      0.408     -79.520      32.457
# tests_per_case                         -0.0058      0.007     -0.794      0.428      -0.020       0.009
# human_development_index              3146.3656   1882.804      1.671      0.097    -571.638    6864.369
# diabetes_prevalence                    43.0202     26.543      1.621      0.107      -9.395      95.435
# positive_rate                        2897.2299    702.610      4.124      0.000    1509.774    4284.686
# aged_70_older                         215.9602    140.384      1.538      0.126     -61.258     493.178
# Africa                                596.5908    381.407      1.564      0.120    -156.579    1349.760
# aged_65_older                         -37.1861     92.571     -0.402      0.688    -219.987     145.615
# North America                        -131.5295    353.714     -0.372      0.710    -830.014     566.955
# Oceania                              -623.3164    530.199     -1.176      0.241   -1670.309     423.676
# ==============================================================================
# Omnibus:                       81.006   Durbin-Watson:                   2.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              295.645
# Skew:                           1.712   Prob(JB):                     6.33e-65
# Kurtosis:                       8.081   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.34e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 857729.1775026498

# %%
# reorder columns according to p-values
# save to `features` variable

deaths_ft = sorted(features, key=lambda col: dth.pvalues[col])
cases_ft = sorted(features, key=lambda col: cas.pvalues[col])

alpha = 0.05

# %%
# stepwise forward regression

def forward_reg(title, features, func):
    if (title is not None):
        print(title)
    
    ft_in_use = []
    for col in features:
        ft_in_use.append(col)

        res = func(X, y, ft_in_use)

        print(f'Added ft:  {col}')
        print(f'Ft in use: {ft_in_use}')

        if (max(res.pvalues) > alpha):
            print(f'Break due to stopping rule: max pvalue = {max(res.pvalues)} > {alpha}')
            break

        print('*' * 20)

# %%
# stepwise forward regression
forward_reg('New deaths per million model:', deaths_ft, new_deaths_per_million)
# Out:
# New deaths per million model:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.335
# Model:                                OLS   Adj. R-squared:                  0.331
# Method:                     Least Squares   F-statistic:                     94.06
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           2.84e-18
# Time:                            23:22:40   Log-Likelihood:                -440.92
# No. Observations:                     189   AIC:                             885.8
# Df Residuals:                         187   BIC:                             892.3
# Df Model:                               1
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.6574      0.249      2.641      0.009       0.166       1.149
# female_smokers     0.1797      0.019      9.699      0.000       0.143       0.216
# ==============================================================================
# Omnibus:                       71.874   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              226.704
# Skew:                           1.558   Prob(JB):                     5.91e-50
# Kurtosis:                       7.367   Cond. No.                         18.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 6.220997954473839
# Added ft:  female_smokers
# Ft in use: ['female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.366
# Model:                                OLS   Adj. R-squared:                  0.359
# Method:                     Least Squares   F-statistic:                     53.58
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           4.20e-19
# Time:                            23:22:40   Log-Likelihood:                -436.43
# No. Observations:                     189   AIC:                             878.9
# Df Residuals:                         186   BIC:                             888.6
# Df Model:                               2
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.7021      0.244      2.875      0.005       0.220       1.184
# female_smokers     0.1881      0.018     10.248      0.000       0.152       0.224
# Oceania           -2.5531      0.848     -3.009      0.003      -4.227      -0.879
# ==============================================================================
# Omnibus:                       76.463   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              236.477
# Skew:                           1.684   Prob(JB):                     4.46e-52
# Kurtosis:                       7.322   Cond. No.                         63.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 5.932232910378907
# Added ft:  Oceania
# Ft in use: ['female_smokers', 'Oceania']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.376
# Model:                                OLS   Adj. R-squared:                  0.365
# Method:                     Least Squares   F-statistic:                     37.09
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           8.14e-19
# Time:                            23:22:40   Log-Likelihood:                -434.92
# No. Observations:                     189   AIC:                             877.8
# Df Residuals:                         185   BIC:                             890.8
# Df Model:                               3
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.9706      0.289      3.363      0.001       0.401       1.540
# female_smokers     0.1796      0.019      9.490      0.000       0.142       0.217
# Oceania           -2.6861      0.848     -3.169      0.002      -4.358      -1.014
# Asia              -0.7398      0.429     -1.723      0.087      -1.587       0.108
# ==============================================================================
# Omnibus:                       75.675   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              234.030
# Skew:                           1.664   Prob(JB):                     1.52e-51
# Kurtosis:                       7.317   Cond. No.                         64.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 5.838593096686277
# Added ft:  Asia
# Ft in use: ['female_smokers', 'Oceania', 'Asia']
# Break due to stopping rule: max pvalue = 0.0866481304381162 > 0.05

# %%
forward_reg('New cases per million model:', cases_ft, new_cases_per_million)
# Out:
# New cases per million model:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.192
# Model:                               OLS   Adj. R-squared:                  0.188
# Method:                    Least Squares   F-statistic:                     44.57
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           2.71e-10
# Time:                           23:22:40   Log-Likelihood:                -1621.1
# No. Observations:                    189   AIC:                             3246.
# Df Residuals:                        187   BIC:                             3253.
# Df Model:                              1
# Covariance Type:               nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            90.2525    153.214      0.589      0.557    -211.997     392.502
# positive_rate  3890.5007    582.742      6.676      0.000    2740.907    5040.094
# ==============================================================================
# Omnibus:                       90.102   Durbin-Watson:                   1.702
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              307.027
# Skew:                           1.988   Prob(JB):                     2.14e-67
# Kurtosis:                       7.814   Cond. No.                         6.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 1650785.4339598846
# Added ft:  positive_rate
# Ft in use: ['positive_rate']
# Break due to stopping rule: max pvalue = 0.556530768744967 > 0.05

# %%
# stepwise backward regression

def backward_reg(title, features, func):
    if (title is not None):
        print(title)
    
    features.reverse()
    ft_in_use = features.copy()
    for col in features:
        ft_in_use.remove(col)

        res = func(X, y, ft_in_use)

        print(f'Removed ft:  {col}')
        print(f'Ft in use: {ft_in_use}')

        if (max(res.pvalues) < alpha):
            print(f'Break due to stopping rule: max pvalue = {max(res.pvalues)} < {alpha}')
            break

        print('*' * 20)

# %%
# stepwise backward regression
backward_reg('New deaths per million model:', deaths_ft, new_deaths_per_million)
# Out:
# New deaths per million model:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.554
# Model:                                OLS   Adj. R-squared:                  0.486
# Method:                     Least Squares   F-statistic:                     8.097
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           5.41e-18
# Time:                            23:22:40   Log-Likelihood:                -403.13
# No. Observations:                     189   AIC:                             858.3
# Df Residuals:                         163   BIC:                             942.5
# Df Model:                              25
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.5011      3.438     -1.600      0.111     -12.289       1.287
# male_smokers                           -0.0017      0.019     -0.091      0.928      -0.039       0.035
# aged_65_older                           0.0271      0.203      0.133      0.894      -0.374       0.429
# aged_70_older                          -0.0415      0.308     -0.135      0.893      -0.650       0.567
# positive_rate                          -0.2490      1.539     -0.162      0.872      -3.289       2.791
# life_expectancy                         0.0128      0.062      0.206      0.837      -0.110       0.136
# tests_per_case                      -4.521e-06    1.6e-05     -0.283      0.778   -3.61e-05    2.71e-05
# North America                          -0.2343      0.776     -0.302      0.763      -1.767       1.298
# new_tests_smoothed_per_thousand        -0.0060      0.017     -0.351      0.726      -0.040       0.028
# extreme_poverty                         0.0063      0.017      0.362      0.717      -0.028       0.041
# population_density                     -0.0001      0.000     -0.457      0.648      -0.001       0.000
# people_vaccinated_per_hundred          -0.0096      0.019     -0.499      0.619      -0.048       0.028
# Europe                                 -0.6201      1.017     -0.610      0.543      -2.628       1.388
# handwashing_facilities                  0.0088      0.014      0.653      0.515      -0.018       0.036
# people_fully_vaccinated_per_hundred    -0.0161      0.019     -0.835      0.405      -0.054       0.022
# cardiovasc_death_rate                   0.0019      0.002      0.881      0.380      -0.002       0.006
# South America                           0.7543      0.848      0.889      0.375      -0.921       2.429
# diabetes_prevalence                     0.0548      0.058      0.939      0.349      -0.060       0.170
# human_development_index                 5.7007      4.121      1.383      0.168      -2.437      13.838
# hospital_beds_per_thousand             -0.1672      0.113     -1.483      0.140      -0.390       0.055
# median_age                              0.1342      0.077      1.744      0.083      -0.018       0.286
# Africa                                 -1.4629      0.838     -1.745      0.083      -3.119       0.193
# gdp_per_capita                      -2.879e-05   1.61e-05     -1.786      0.076   -6.06e-05    3.05e-06
# total_boosters_per_hundred             -0.0303      0.016     -1.862      0.064      -0.062       0.002
# Asia                                   -1.4534      0.766     -1.897      0.060      -2.966       0.059
# Oceania                                -2.4847      1.126     -2.206      0.029      -4.708      -0.261
# female_smokers                          0.1232      0.033      3.679      0.000       0.057       0.189
# ==============================================================================
# Omnibus:                       48.676   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.327
# Skew:                           1.125   Prob(JB):                     3.33e-26
# Kurtosis:                       6.136   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.34e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 4.170652956434397
# Removed ft:  stringency_index
# Ft in use: ['male_smokers', 'aged_65_older', 'aged_70_older', 'positive_rate', 'life_expectancy', 'tests_per_case', 'North America', 'new_tests_smoothed_per_thousand', 'extreme_poverty', 'population_density', 'people_vaccinated_per_hundred', 'Europe', 'handwashing_facilities', 'people_fully_vaccinated_per_hundred', 'cardiovasc_death_rate', 'South America', 'diabetes_prevalence', 'human_development_index', 'hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.554
# Model:                                OLS   Adj. R-squared:                  0.489
# Method:                     Least Squares   F-statistic:                     8.486
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.83e-18
# Time:                            23:22:40   Log-Likelihood:                -403.14
# No. Observations:                     189   AIC:                             856.3
# Df Residuals:                         164   BIC:                             937.3
# Df Model:                              24
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.5175      3.423     -1.612      0.109     -12.275       1.240
# aged_65_older                           0.0284      0.202      0.140      0.889      -0.371       0.428
# aged_70_older                          -0.0420      0.307     -0.137      0.891      -0.649       0.565
# positive_rate                          -0.2654      1.524     -0.174      0.862      -3.275       2.744
# life_expectancy                         0.0131      0.062      0.211      0.833      -0.109       0.135
# tests_per_case                       -4.57e-06   1.59e-05     -0.287      0.775    -3.6e-05    2.69e-05
# North America                          -0.2261      0.769     -0.294      0.769      -1.744       1.291
# new_tests_smoothed_per_thousand        -0.0062      0.017     -0.371      0.711      -0.039       0.027
# extreme_poverty                         0.0064      0.017      0.366      0.715      -0.028       0.041
# population_density                     -0.0001      0.000     -0.464      0.644      -0.001       0.000
# people_vaccinated_per_hundred          -0.0097      0.019     -0.506      0.613      -0.048       0.028
# Europe                                 -0.6171      1.013     -0.609      0.543      -2.618       1.384
# handwashing_facilities                  0.0087      0.013      0.650      0.517      -0.018       0.035
# people_fully_vaccinated_per_hundred    -0.0162      0.019     -0.844      0.400      -0.054       0.022
# cardiovasc_death_rate                   0.0019      0.002      0.891      0.374      -0.002       0.006
# South America                           0.7642      0.839      0.911      0.364      -0.892       2.420
# diabetes_prevalence                     0.0543      0.058      0.938      0.350      -0.060       0.169
# human_development_index                 5.7133      4.106      1.391      0.166      -2.395      13.821
# hospital_beds_per_thousand             -0.1689      0.111     -1.523      0.130      -0.388       0.050
# median_age                              0.1335      0.076      1.750      0.082      -0.017       0.284
# Africa                                 -1.4761      0.823     -1.793      0.075      -3.102       0.149
# gdp_per_capita                      -2.848e-05   1.57e-05     -1.812      0.072   -5.95e-05    2.56e-06
# total_boosters_per_hundred             -0.0303      0.016     -1.865      0.064      -0.062       0.002
# Asia                                   -1.4715      0.737     -1.996      0.048      -2.927      -0.016
# Oceania                                -2.4908      1.121     -2.223      0.028      -4.704      -0.278
# female_smokers                          0.1222      0.032      3.852      0.000       0.060       0.185
# ==============================================================================
# Omnibus:                       48.583   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.136
# Skew:                           1.123   Prob(JB):                     3.67e-26
# Kurtosis:                       6.135   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.34e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 4.170862702247255
# Removed ft:  male_smokers
# Ft in use: ['aged_65_older', 'aged_70_older', 'positive_rate', 'life_expectancy', 'tests_per_case', 'North America', 'new_tests_smoothed_per_thousand', 'extreme_poverty', 'population_density', 'people_vaccinated_per_hundred', 'Europe', 'handwashing_facilities', 'people_fully_vaccinated_per_hundred', 'cardiovasc_death_rate', 'South America', 'diabetes_prevalence', 'human_development_index', 'hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.554
# Model:                                OLS   Adj. R-squared:                  0.492
# Method:                     Least Squares   F-statistic:                     8.907
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           6.07e-19
# Time:                            23:22:40   Log-Likelihood:                -403.15
# No. Observations:                     189   AIC:                             854.3
# Df Residuals:                         165   BIC:                             932.1
# Df Model:                              23
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.5156      3.412     -1.616      0.108     -12.253       1.222
# aged_70_older                          -0.0039      0.143     -0.027      0.978      -0.287       0.279
# positive_rate                          -0.2673      1.520     -0.176      0.861      -3.268       2.733
# life_expectancy                         0.0127      0.062      0.206      0.837      -0.109       0.135
# tests_per_case                      -4.228e-06   1.57e-05     -0.269      0.788   -3.52e-05    2.68e-05
# North America                          -0.2214      0.766     -0.289      0.773      -1.733       1.290
# new_tests_smoothed_per_thousand        -0.0064      0.017     -0.388      0.699      -0.039       0.026
# extreme_poverty                         0.0064      0.017      0.368      0.713      -0.028       0.041
# population_density                     -0.0001      0.000     -0.444      0.657      -0.001       0.000
# people_vaccinated_per_hundred          -0.0097      0.019     -0.507      0.613      -0.047       0.028
# Europe                                 -0.6057      1.007     -0.601      0.548      -2.594       1.383
# handwashing_facilities                  0.0087      0.013      0.647      0.518      -0.018       0.035
# people_fully_vaccinated_per_hundred    -0.0162      0.019     -0.847      0.398      -0.054       0.022
# cardiovasc_death_rate                   0.0019      0.002      0.900      0.370      -0.002       0.006
# South America                           0.7673      0.836      0.918      0.360      -0.883       2.418
# diabetes_prevalence                     0.0546      0.058      0.946      0.346      -0.059       0.169
# human_development_index                 5.7783      4.068      1.420      0.157      -2.254      13.810
# hospital_beds_per_thousand             -0.1690      0.111     -1.528      0.128      -0.387       0.049
# median_age                              0.1338      0.076      1.760      0.080      -0.016       0.284
# Africa                                 -1.4811      0.820     -1.806      0.073      -3.100       0.138
# gdp_per_capita                      -2.849e-05   1.57e-05     -1.817      0.071   -5.94e-05    2.46e-06
# total_boosters_per_hundred             -0.0303      0.016     -1.872      0.063      -0.062       0.002
# Asia                                   -1.4793      0.733     -2.018      0.045      -2.927      -0.032
# Oceania                                -2.4953      1.117     -2.234      0.027      -4.701      -0.290
# female_smokers                          0.1225      0.032      3.879      0.000       0.060       0.185
# ==============================================================================
# Omnibus:                       48.641   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.001
# Skew:                           1.125   Prob(JB):                     3.92e-26
# Kurtosis:                       6.129   Cond. No.                     2.84e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.72e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 4.1713633915874
# Removed ft:  aged_65_older
# Ft in use: ['aged_70_older', 'positive_rate', 'life_expectancy', 'tests_per_case', 'North America', 'new_tests_smoothed_per_thousand', 'extreme_poverty', 'population_density', 'people_vaccinated_per_hundred', 'Europe', 'handwashing_facilities', 'people_fully_vaccinated_per_hundred', 'cardiovasc_death_rate', 'South America', 'diabetes_prevalence', 'human_development_index', 'hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.554
# Model:                                OLS   Adj. R-squared:                  0.495
# Method:                     Least Squares   F-statistic:                     9.368
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.95e-19
# Time:                            23:22:40   Log-Likelihood:                -403.15
# No. Observations:                     189   AIC:                             852.3
# Df Residuals:                         166   BIC:                             926.9
# Df Model:                              22
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.4921      3.291     -1.669      0.097     -11.990       1.006
# positive_rate                          -0.2722      1.504     -0.181      0.857      -3.243       2.698
# life_expectancy                         0.0125      0.061      0.205      0.838      -0.108       0.133
# tests_per_case                      -4.194e-06   1.56e-05     -0.269      0.788    -3.5e-05    2.66e-05
# North America                          -0.2182      0.754     -0.289      0.773      -1.707       1.271
# new_tests_smoothed_per_thousand        -0.0065      0.017     -0.389      0.698      -0.039       0.026
# extreme_poverty                         0.0063      0.017      0.368      0.713      -0.028       0.040
# population_density                     -0.0001      0.000     -0.447      0.656      -0.001       0.000
# people_vaccinated_per_hundred          -0.0096      0.019     -0.510      0.611      -0.047       0.028
# Europe                                 -0.6053      1.004     -0.603      0.547      -2.587       1.377
# handwashing_facilities                  0.0087      0.013      0.656      0.513      -0.017       0.035
# people_fully_vaccinated_per_hundred    -0.0163      0.019     -0.851      0.396      -0.054       0.021
# cardiovasc_death_rate                   0.0019      0.002      0.923      0.357      -0.002       0.006
# South America                           0.7734      0.803      0.963      0.337      -0.812       2.359
# diabetes_prevalence                     0.0552      0.053      1.038      0.301      -0.050       0.160
# human_development_index                 5.7816      4.054      1.426      0.156      -2.222      13.785
# hospital_beds_per_thousand             -0.1695      0.109     -1.561      0.120      -0.384       0.045
# median_age                              0.1324      0.054      2.454      0.015       0.026       0.239
# Africa                                 -1.4761      0.797     -1.853      0.066      -3.049       0.097
# gdp_per_capita                      -2.839e-05   1.52e-05     -1.870      0.063   -5.84e-05    1.59e-06
# total_boosters_per_hundred             -0.0303      0.016     -1.891      0.060      -0.062       0.001
# Asia                                   -1.4720      0.679     -2.167      0.032      -2.813      -0.131
# Oceania                                -2.4940      1.112     -2.242      0.026      -4.690      -0.298
# female_smokers                          0.1223      0.031      3.985      0.000       0.062       0.183
# ==============================================================================
# Omnibus:                       48.641   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.037
# Skew:                           1.125   Prob(JB):                     3.85e-26
# Kurtosis:                       6.130   Cond. No.                     2.84e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.72e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 4.17138200136944
# Removed ft:  aged_70_older
# Ft in use: ['positive_rate', 'life_expectancy', 'tests_per_case', 'North America', 'new_tests_smoothed_per_thousand', 'extreme_poverty', 'population_density', 'people_vaccinated_per_hundred', 'Europe', 'handwashing_facilities', 'people_fully_vaccinated_per_hundred', 'cardiovasc_death_rate', 'South America', 'diabetes_prevalence', 'human_development_index', 'hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.554
# Model:                                OLS   Adj. R-squared:                  0.498
# Method:                     Least Squares   F-statistic:                     9.870
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           6.18e-20
# Time:                            23:22:40   Log-Likelihood:                -403.17
# No. Observations:                     189   AIC:                             850.3
# Df Residuals:                         167   BIC:                             921.7
# Df Model:                              21
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.4148      3.254     -1.664      0.098     -11.839       1.009
# life_expectancy                         0.0108      0.060      0.180      0.857      -0.108       0.129
# tests_per_case                      -4.353e-06   1.55e-05     -0.280      0.780    -3.5e-05    2.63e-05
# North America                          -0.2028      0.747     -0.271      0.786      -1.678       1.272
# new_tests_smoothed_per_thousand        -0.0054      0.015     -0.349      0.728      -0.036       0.025
# extreme_poverty                         0.0063      0.017      0.364      0.716      -0.028       0.040
# population_density                     -0.0001      0.000     -0.451      0.652      -0.001       0.000
# people_vaccinated_per_hundred          -0.0093      0.019     -0.498      0.619      -0.046       0.028
# Europe                                 -0.6246      0.995     -0.627      0.531      -2.590       1.340
# handwashing_facilities                  0.0086      0.013      0.651      0.516      -0.017       0.035
# people_fully_vaccinated_per_hundred    -0.0164      0.019     -0.859      0.392      -0.054       0.021
# cardiovasc_death_rate                   0.0018      0.002      0.910      0.364      -0.002       0.006
# South America                           0.7498      0.790      0.949      0.344      -0.810       2.309
# diabetes_prevalence                     0.0560      0.053      1.061      0.290      -0.048       0.160
# human_development_index                 5.6669      3.992      1.419      0.158      -2.215      13.549
# hospital_beds_per_thousand             -0.1687      0.108     -1.559      0.121      -0.382       0.045
# median_age                              0.1338      0.053      2.514      0.013       0.029       0.239
# Africa                                 -1.4221      0.736     -1.931      0.055      -2.876       0.032
# gdp_per_capita                      -2.825e-05   1.51e-05     -1.869      0.063   -5.81e-05     1.6e-06
# total_boosters_per_hundred             -0.0302      0.016     -1.890      0.060      -0.062       0.001
# Asia                                   -1.4589      0.673     -2.166      0.032      -2.789      -0.129
# Oceania                                -2.4563      1.090     -2.254      0.025      -4.607      -0.305
# female_smokers                          0.1221      0.031      3.993      0.000       0.062       0.183
# ==============================================================================
# Omnibus:                       48.761   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.047
# Skew:                           1.125   Prob(JB):                     2.33e-26
# Kurtosis:                       6.150   Cond. No.                     3.44e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.17e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 4.172204380899474
# Removed ft:  positive_rate
# Ft in use: ['life_expectancy', 'tests_per_case', 'North America', 'new_tests_smoothed_per_thousand', 'extreme_poverty', 'population_density', 'people_vaccinated_per_hundred', 'Europe', 'handwashing_facilities', 'people_fully_vaccinated_per_hundred', 'cardiovasc_death_rate', 'South America', 'diabetes_prevalence', 'human_development_index', 'hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.554
# Model:                                OLS   Adj. R-squared:                  0.501
# Method:                     Least Squares   F-statistic:                     10.42
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.90e-20
# Time:                            23:22:40   Log-Likelihood:                -403.19
# No. Observations:                     189   AIC:                             848.4
# Df Residuals:                         168   BIC:                             916.4
# Df Model:                              20
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -4.9479      1.968     -2.515      0.013      -8.832      -1.063
# tests_per_case                      -4.404e-06   1.55e-05     -0.284      0.776    -3.5e-05    2.62e-05
# North America                          -0.1213      0.594     -0.204      0.838      -1.293       1.051
# new_tests_smoothed_per_thousand        -0.0055      0.015     -0.356      0.722      -0.036       0.025
# extreme_poverty                         0.0062      0.017      0.362      0.718      -0.028       0.040
# population_density                     -0.0001      0.000     -0.438      0.662      -0.001       0.000
# people_vaccinated_per_hundred          -0.0092      0.019     -0.495      0.622      -0.046       0.028
# Europe                                 -0.5504      0.904     -0.609      0.543      -2.335       1.234
# handwashing_facilities                  0.0090      0.013      0.687      0.493      -0.017       0.035
# people_fully_vaccinated_per_hundred    -0.0161      0.019     -0.850      0.397      -0.053       0.021
# cardiovasc_death_rate                   0.0018      0.002      0.896      0.372      -0.002       0.006
# South America                           0.8220      0.679      1.211      0.228      -0.518       2.163
# diabetes_prevalence                     0.0568      0.052      1.083      0.281      -0.047       0.160
# human_development_index                 5.9056      3.756      1.572      0.118      -1.509      13.321
# hospital_beds_per_thousand             -0.1712      0.107     -1.599      0.112      -0.383       0.040
# median_age                              0.1358      0.052      2.617      0.010       0.033       0.238
# Africa                                 -1.3594      0.648     -2.099      0.037      -2.638      -0.081
# gdp_per_capita                      -2.841e-05   1.51e-05     -1.887      0.061   -5.81e-05    1.31e-06
# total_boosters_per_hundred             -0.0300      0.016     -1.888      0.061      -0.061       0.001
# Asia                                   -1.3769      0.496     -2.778      0.006      -2.355      -0.398
# Oceania                                -2.3619      0.953     -2.478      0.014      -4.243      -0.480
# female_smokers                          0.1220      0.030      4.001      0.000       0.062       0.182
# ==============================================================================
# Omnibus:                       49.017   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.728
# Skew:                           1.131   Prob(JB):                     1.65e-26
# Kurtosis:                       6.156   Cond. No.                     2.68e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.94e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 4.173017965358773
# Removed ft:  life_expectancy
# Ft in use: ['tests_per_case', 'North America', 'new_tests_smoothed_per_thousand', 'extreme_poverty', 'population_density', 'people_vaccinated_per_hundred', 'Europe', 'handwashing_facilities', 'people_fully_vaccinated_per_hundred', 'cardiovasc_death_rate', 'South America', 'diabetes_prevalence', 'human_development_index', 'hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.553
# Model:                                OLS   Adj. R-squared:                  0.503
# Method:                     Least Squares   F-statistic:                     11.03
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           5.83e-21
# Time:                            23:22:40   Log-Likelihood:                -403.23
# No. Observations:                     189   AIC:                             846.5
# Df Residuals:                         169   BIC:                             911.3
# Df Model:                              19
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -4.9472      1.962     -2.521      0.013      -8.821      -1.074
# North America                          -0.1176      0.592     -0.199      0.843      -1.286       1.051
# new_tests_smoothed_per_thousand        -0.0057      0.015     -0.369      0.712      -0.036       0.025
# extreme_poverty                         0.0062      0.017      0.361      0.718      -0.028       0.040
# population_density                  -9.694e-05      0.000     -0.421      0.674      -0.001       0.000
# people_vaccinated_per_hundred          -0.0093      0.019     -0.497      0.620      -0.046       0.028
# Europe                                 -0.5407      0.901     -0.600      0.549      -2.319       1.237
# handwashing_facilities                  0.0090      0.013      0.691      0.490      -0.017       0.035
# people_fully_vaccinated_per_hundred    -0.0164      0.019     -0.869      0.386      -0.054       0.021
# cardiovasc_death_rate                   0.0017      0.002      0.897      0.371      -0.002       0.006
# South America                           0.8249      0.677      1.218      0.225      -0.512       2.162
# diabetes_prevalence                     0.0564      0.052      1.079      0.282      -0.047       0.160
# human_development_index                 6.0075      3.729      1.611      0.109      -1.353      13.368
# hospital_beds_per_thousand             -0.1720      0.107     -1.611      0.109      -0.383       0.039
# median_age                              0.1337      0.051      2.610      0.010       0.033       0.235
# Africa                                 -1.3655      0.645     -2.116      0.036      -2.640      -0.091
# gdp_per_capita                       -2.82e-05    1.5e-05     -1.881      0.062   -5.78e-05     1.4e-06
# total_boosters_per_hundred             -0.0302      0.016     -1.907      0.058      -0.061       0.001
# Asia                                   -1.3851      0.493     -2.807      0.006      -2.359      -0.411
# Oceania                                -2.3633      0.950     -2.486      0.014      -4.240      -0.487
# female_smokers                          0.1226      0.030      4.042      0.000       0.063       0.182
# ==============================================================================
# Omnibus:                       48.952   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.077
# Skew:                           1.131   Prob(JB):                     2.29e-26
# Kurtosis:                       6.142   Cond. No.                     3.25e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.31e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 4.175027252393962
# Removed ft:  tests_per_case
# Ft in use: ['North America', 'new_tests_smoothed_per_thousand', 'extreme_poverty', 'population_density', 'people_vaccinated_per_hundred', 'Europe', 'handwashing_facilities', 'people_fully_vaccinated_per_hundred', 'cardiovasc_death_rate', 'South America', 'diabetes_prevalence', 'human_development_index', 'hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.553
# Model:                                OLS   Adj. R-squared:                  0.503
# Method:                     Least Squares   F-statistic:                     11.03
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           5.83e-21
# Time:                            23:22:40   Log-Likelihood:                -403.23
# No. Observations:                     189   AIC:                             846.5
# Df Residuals:                         169   BIC:                             911.3
# Df Model:                              19
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.0648      2.323     -2.180      0.031      -9.651      -0.478
# new_tests_smoothed_per_thousand        -0.0057      0.015     -0.369      0.712      -0.036       0.025
# extreme_poverty                         0.0062      0.017      0.361      0.718      -0.028       0.040
# population_density                  -9.694e-05      0.000     -0.421      0.674      -0.001       0.000
# people_vaccinated_per_hundred          -0.0093      0.019     -0.497      0.620      -0.046       0.028
# Europe                                 -0.4231      0.931     -0.455      0.650      -2.260       1.414
# handwashing_facilities                  0.0090      0.013      0.691      0.490      -0.017       0.035
# people_fully_vaccinated_per_hundred    -0.0164      0.019     -0.869      0.386      -0.054       0.021
# cardiovasc_death_rate                   0.0017      0.002      0.897      0.371      -0.002       0.006
# South America                           0.9425      0.825      1.142      0.255      -0.686       2.571
# diabetes_prevalence                     0.0564      0.052      1.079      0.282      -0.047       0.160
# human_development_index                 6.0075      3.729      1.611      0.109      -1.353      13.368
# hospital_beds_per_thousand             -0.1720      0.107     -1.611      0.109      -0.383       0.039
# median_age                              0.1337      0.051      2.610      0.010       0.033       0.235
# Africa                                 -1.2479      0.881     -1.416      0.159      -2.988       0.492
# gdp_per_capita                       -2.82e-05    1.5e-05     -1.881      0.062   -5.78e-05     1.4e-06
# total_boosters_per_hundred             -0.0302      0.016     -1.907      0.058      -0.061       0.001
# Asia                                   -1.2675      0.620     -2.045      0.042      -2.491      -0.044
# Oceania                                -2.2458      1.175     -1.911      0.058      -4.565       0.074
# female_smokers                          0.1226      0.030      4.042      0.000       0.063       0.182
# ==============================================================================
# Omnibus:                       48.952   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.077
# Skew:                           1.131   Prob(JB):                     2.29e-26
# Kurtosis:                       6.142   Cond. No.                     7.08e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 4.175027252393959
# Removed ft:  North America
# Ft in use: ['new_tests_smoothed_per_thousand', 'extreme_poverty', 'population_density', 'people_vaccinated_per_hundred', 'Europe', 'handwashing_facilities', 'people_fully_vaccinated_per_hundred', 'cardiovasc_death_rate', 'South America', 'diabetes_prevalence', 'human_development_index', 'hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.553
# Model:                                OLS   Adj. R-squared:                  0.506
# Method:                     Least Squares   F-statistic:                     11.69
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.78e-21
# Time:                            23:22:40   Log-Likelihood:                -403.31
# No. Observations:                     189   AIC:                             844.6
# Df Residuals:                         170   BIC:                             906.2
# Df Model:                              18
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -4.9894      2.308     -2.161      0.032      -9.546      -0.433
# extreme_poverty                         0.0060      0.017      0.350      0.726      -0.028       0.040
# population_density                     -0.0001      0.000     -0.513      0.609      -0.001       0.000
# people_vaccinated_per_hundred          -0.0085      0.018     -0.459      0.647      -0.045       0.028
# Europe                                 -0.4913      0.910     -0.540      0.590      -2.287       1.305
# handwashing_facilities                  0.0091      0.013      0.705      0.481      -0.016       0.035
# people_fully_vaccinated_per_hundred    -0.0170      0.019     -0.907      0.366      -0.054       0.020
# cardiovasc_death_rate                   0.0018      0.002      0.913      0.363      -0.002       0.006
# South America                           0.9343      0.823      1.136      0.258      -0.690       2.558
# diabetes_prevalence                     0.0543      0.052      1.048      0.296      -0.048       0.157
# human_development_index                 5.8609      3.698      1.585      0.115      -1.439      13.161
# hospital_beds_per_thousand             -0.1691      0.106     -1.593      0.113      -0.379       0.040
# median_age                              0.1346      0.051      2.637      0.009       0.034       0.235
# Africa                                 -1.2628      0.878     -1.438      0.152      -2.996       0.471
# gdp_per_capita                      -2.796e-05   1.49e-05     -1.871      0.063   -5.75e-05    1.53e-06
# total_boosters_per_hundred             -0.0313      0.016     -2.019      0.045      -0.062      -0.001
# Asia                                   -1.2845      0.617     -2.084      0.039      -2.502      -0.068
# Oceania                                -2.2380      1.172     -1.910      0.058      -4.551       0.075
# female_smokers                          0.1230      0.030      4.066      0.000       0.063       0.183
# ==============================================================================
# Omnibus:                       48.730   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.152
# Skew:                           1.128   Prob(JB):                     3.64e-26
# Kurtosis:                       6.129   Cond. No.                     7.04e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.04e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 4.1783956361891885
# Removed ft:  new_tests_smoothed_per_thousand
# Ft in use: ['extreme_poverty', 'population_density', 'people_vaccinated_per_hundred', 'Europe', 'handwashing_facilities', 'people_fully_vaccinated_per_hundred', 'cardiovasc_death_rate', 'South America', 'diabetes_prevalence', 'human_development_index', 'hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.553
# Model:                                OLS   Adj. R-squared:                  0.508
# Method:                     Least Squares   F-statistic:                     12.43
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           5.22e-22
# Time:                            23:22:40   Log-Likelihood:                -403.38
# No. Observations:                     189   AIC:                             842.8
# Df Residuals:                         171   BIC:                             901.1
# Df Model:                              17
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -4.5520      1.937     -2.350      0.020      -8.375      -0.729
# population_density                     -0.0001      0.000     -0.491      0.624      -0.001       0.000
# people_vaccinated_per_hundred          -0.0091      0.018     -0.494      0.622      -0.045       0.027
# Europe                                 -0.4776      0.907     -0.527      0.599      -2.267       1.312
# handwashing_facilities                  0.0081      0.013      0.644      0.520      -0.017       0.033
# people_fully_vaccinated_per_hundred    -0.0166      0.019     -0.891      0.374      -0.053       0.020
# cardiovasc_death_rate                   0.0017      0.002      0.890      0.375      -0.002       0.006
# South America                           0.9127      0.818      1.115      0.266      -0.703       2.528
# diabetes_prevalence                     0.0506      0.051      1.000      0.319      -0.049       0.151
# human_development_index                 5.5202      3.559      1.551      0.123      -1.505      12.545
# hospital_beds_per_thousand             -0.1682      0.106     -1.589      0.114      -0.377       0.041
# median_age                              0.1337      0.051      2.630      0.009       0.033       0.234
# Africa                                 -1.2225      0.868     -1.408      0.161      -2.937       0.492
# gdp_per_capita                      -2.729e-05   1.48e-05     -1.846      0.067   -5.65e-05    1.88e-06
# total_boosters_per_hundred             -0.0313      0.015     -2.022      0.045      -0.062      -0.001
# Asia                                   -1.3035      0.613     -2.128      0.035      -2.513      -0.094
# Oceania                                -2.2627      1.167     -1.939      0.054      -4.566       0.040
# female_smokers                          0.1236      0.030      4.104      0.000       0.064       0.183
# ==============================================================================
# Omnibus:                       48.843   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.725
# Skew:                           1.129   Prob(JB):                     2.73e-26
# Kurtosis:                       6.138   Cond. No.                     6.61e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.61e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 4.181413099031785
# Removed ft:  extreme_poverty
# ...
# ==============================================================================
# Omnibus:                       55.609   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.156
# Skew:                           1.278   Prob(JB):                     1.00e-30
# Kurtosis:                       6.318   Cond. No.                     2.17e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 4.473552311528392
# Removed ft:  human_development_index
# Ft in use: ['hospital_beds_per_thousand', 'median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.518
# Model:                                OLS   Adj. R-squared:                  0.500
# Method:                     Least Squares   F-statistic:                     27.84
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           9.22e-26
# Time:                            23:22:40   Log-Likelihood:                -410.36
# No. Observations:                     189   AIC:                             836.7
# Df Residuals:                         181   BIC:                             862.7
# Df Model:                               7
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.2980      1.022      0.292      0.771      -1.718       2.314
# median_age                     0.1116      0.033      3.428      0.001       0.047       0.176
# Africa                        -2.3336      0.587     -3.972      0.000      -3.493      -1.174
# gdp_per_capita             -1.939e-05   1.17e-05     -1.661      0.098   -4.24e-05    3.64e-06
# total_boosters_per_hundred    -0.0471      0.014     -3.384      0.001      -0.075      -0.020
# Asia                          -1.6101      0.478     -3.366      0.001      -2.554      -0.666
# Oceania                       -2.2656      0.831     -2.728      0.007      -3.905      -0.627
# female_smokers                 0.1191      0.025      4.724      0.000       0.069       0.169
# ==============================================================================
# Omnibus:                       57.859   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.476
# Skew:                           1.320   Prob(JB):                     9.46e-33
# Kurtosis:                       6.428   Cond. No.                     2.09e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 4.502251881424033
# Removed ft:  hospital_beds_per_thousand
# Ft in use: ['median_age', 'Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.487
# Model:                                OLS   Adj. R-squared:                  0.470
# Method:                     Least Squares   F-statistic:                     28.82
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           4.17e-24
# Time:                            23:22:40   Log-Likelihood:                -416.31
# No. Observations:                     189   AIC:                             846.6
# Df Residuals:                         182   BIC:                             869.3
# Df Model:                               6
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          3.4173      0.478      7.143      0.000       2.473       4.361
# Africa                        -3.2688      0.535     -6.105      0.000      -4.325      -2.212
# gdp_per_capita             -2.602e-06   1.09e-05     -0.239      0.812   -2.41e-05    1.89e-05
# total_boosters_per_hundred    -0.0457      0.014     -3.186      0.002      -0.074      -0.017
# Asia                          -1.8914      0.485     -3.900      0.000      -2.848      -0.935
# Oceania                       -3.2192      0.805     -3.997      0.000      -4.809      -1.630
# female_smokers                 0.1528      0.024      6.396      0.000       0.106       0.200
# ==============================================================================
# Omnibus:                       59.695   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              148.821
# Skew:                           1.377   Prob(JB):                     4.83e-33
# Kurtosis:                       6.364   Cond. No.                     1.43e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 4.794587011151457
# Removed ft:  median_age
# Ft in use: ['Africa', 'gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.382
# Model:                                OLS   Adj. R-squared:                  0.365
# Method:                     Least Squares   F-statistic:                     22.64
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.18e-17
# Time:                            23:22:40   Log-Likelihood:                -433.91
# No. Observations:                     189   AIC:                             879.8
# Df Residuals:                         183   BIC:                             899.3
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          1.0332      0.303      3.415      0.001       0.436       1.630
# gdp_per_capita               2.81e-06   1.19e-05      0.236      0.814   -2.07e-05    2.63e-05
# total_boosters_per_hundred    -0.0194      0.015     -1.298      0.196      -0.049       0.010
# Asia                          -0.4857      0.467     -1.039      0.300      -1.407       0.436
# Oceania                       -2.5086      0.872     -2.875      0.005      -4.230      -0.787
# female_smokers                 0.2014      0.025      8.163      0.000       0.153       0.250
# ==============================================================================
# Omnibus:                       70.867   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              197.903
# Skew:                           1.598   Prob(JB):                     1.06e-43
# Kurtosis:                       6.862   Cond. No.                     1.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 5.776431257233006
# Removed ft:  Africa
# Ft in use: ['gdp_per_capita', 'total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.382
# Model:                                OLS   Adj. R-squared:                  0.369
# Method:                     Least Squares   F-statistic:                     28.44
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           2.12e-18
# Time:                            23:22:40   Log-Likelihood:                -433.94
# No. Observations:                     189   AIC:                             877.9
# Df Residuals:                         184   BIC:                             894.1
# Df Model:                               4
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          1.0498      0.294      3.576      0.000       0.471       1.629
# total_boosters_per_hundred    -0.0175      0.013     -1.387      0.167      -0.043       0.007
# Asia                          -0.4855      0.466     -1.042      0.299      -1.405       0.434
# Oceania                       -2.5516      0.851     -2.998      0.003      -4.231      -0.873
# female_smokers                 0.2015      0.025      8.189      0.000       0.153       0.250
# ==============================================================================
# Omnibus:                       70.970   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              199.159
# Skew:                           1.598   Prob(JB):                     5.67e-44
# Kurtosis:                       6.883   Cond. No.                         142.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 5.778191988714312
# Removed ft:  gdp_per_capita
# Ft in use: ['total_boosters_per_hundred', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.376
# Model:                                OLS   Adj. R-squared:                  0.365
# Method:                     Least Squares   F-statistic:                     37.09
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           8.14e-19
# Time:                            23:22:41   Log-Likelihood:                -434.92
# No. Observations:                     189   AIC:                             877.8
# Df Residuals:                         185   BIC:                             890.8
# Df Model:                               3
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.9706      0.289      3.363      0.001       0.401       1.540
# Asia              -0.7398      0.429     -1.723      0.087      -1.587       0.108
# Oceania           -2.6861      0.848     -3.169      0.002      -4.358      -1.014
# female_smokers     0.1796      0.019      9.490      0.000       0.142       0.217
# ==============================================================================
# Omnibus:                       75.675   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              234.030
# Skew:                           1.664   Prob(JB):                     1.52e-51
# Kurtosis:                       7.317   Cond. No.                         64.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 5.838593096686277
# Removed ft:  total_boosters_per_hundred
# Ft in use: ['Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.366
# Model:                                OLS   Adj. R-squared:                  0.359
# Method:                     Least Squares   F-statistic:                     53.58
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           4.20e-19
# Time:                            23:22:41   Log-Likelihood:                -436.43
# No. Observations:                     189   AIC:                             878.9
# Df Residuals:                         186   BIC:                             888.6
# Df Model:                               2
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.7021      0.244      2.875      0.005       0.220       1.184
# Oceania           -2.5531      0.848     -3.009      0.003      -4.227      -0.879
# female_smokers     0.1881      0.018     10.248      0.000       0.152       0.224
# ==============================================================================
# Omnibus:                       76.463   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              236.477
# Skew:                           1.684   Prob(JB):                     4.46e-52
# Kurtosis:                       7.322   Cond. No.                         63.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 5.932232910378905
# Removed ft:  Asia
# Ft in use: ['Oceania', 'female_smokers']
# Break due to stopping rule: max pvalue = 0.004512993909090609 < 0.05

# %%
backward_reg('New cases per million model:', cases_ft, new_cases_per_million)
# Out:
# New cases per million model:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.580
# Model:                               OLS   Adj. R-squared:                  0.516
# Method:                    Least Squares   F-statistic:                     9.019
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           6.25e-20
# Time:                           23:22:41   Log-Likelihood:                -1559.2
# No. Observations:                    189   AIC:                             3170.
# Df Residuals:                        163   BIC:                             3255.
# Df Model:                             25
# Covariance Type:               nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                -239.3836   1558.991     -0.154      0.878   -3317.805    2839.038
# gdp_per_capita                      -7.918e-05      0.007     -0.011      0.991      -0.015       0.014
# people_fully_vaccinated_per_hundred    -1.2390      8.757     -0.141      0.888     -18.530      16.052
# extreme_poverty                         1.4813      7.902      0.187      0.852     -14.122      17.084
# people_vaccinated_per_hundred           1.8102      8.741      0.207      0.836     -15.450      19.070
# handwashing_facilities                 -2.1965      6.127     -0.358      0.720     -14.295       9.902
# North America                        -131.4492    351.959     -0.373      0.709    -826.437     563.538
# cardiovasc_death_rate                  -0.3738      0.986     -0.379      0.705      -2.321       1.573
# female_smokers                          6.1123     15.182      0.403      0.688     -23.866      36.091
# aged_65_older                         -37.1994     92.217     -0.403      0.687    -219.293     144.894
# male_smokers                           -4.0535      8.489     -0.477      0.634     -20.816      12.709
# Europe                                266.8844    461.202      0.579      0.564    -643.817    1177.585
# Asia                                  205.5720    347.417      0.592      0.555    -480.446     891.590
# tests_per_case                         -0.0058      0.007     -0.797      0.427      -0.020       0.009
# life_expectancy                       -23.5264     28.226     -0.833      0.406     -79.263      32.210
# population_density                     -0.1097      0.110     -0.997      0.320      -0.327       0.108
# Oceania                              -623.8210    510.692     -1.222      0.224   -1632.245     384.603
# median_age                            -47.5372     34.905     -1.362      0.175    -116.462      21.388
# South America                        -553.1664    384.725     -1.438      0.152   -1312.855     206.522
# hospital_beds_per_thousand            -78.7822     51.148     -1.540      0.125    -179.780      22.216
# aged_70_older                         215.9816    139.833      1.545      0.124     -60.136     492.099
# Africa                                596.5966    380.232      1.569      0.119    -154.218    1347.411
# diabetes_prevalence                    43.0186     26.458      1.626      0.106      -9.226      95.263
# human_development_index              3145.7203   1868.906      1.683      0.094    -544.668    6836.109
# total_boosters_per_hundred             17.9088      7.387      2.425      0.016       3.323      32.495
# new_tests_smoothed_per_thousand        29.8441      7.724      3.864      0.000      14.593      45.095
# positive_rate                        2897.4433    698.075      4.151      0.000    1519.007    4275.880
# ==============================================================================
# Omnibus:                       81.011   Durbin-Watson:                   2.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              295.691
# Skew:                           1.712   Prob(JB):                     6.19e-65
# Kurtosis:                       8.082   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.34e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 857729.2496083024
# Removed ft:  stringency_index
# Ft in use: ['gdp_per_capita', 'people_fully_vaccinated_per_hundred', 'extreme_poverty', 'people_vaccinated_per_hundred', 'handwashing_facilities', 'North America', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.580
# Model:                               OLS   Adj. R-squared:                  0.519
# Method:                    Least Squares   F-statistic:                     9.453
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           2.00e-20
# Time:                           23:22:41   Log-Likelihood:                -1559.2
# No. Observations:                    189   AIC:                             3168.
# Df Residuals:                        164   BIC:                             3250.
# Df Model:                             24
# Covariance Type:               nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                -235.6332   1515.401     -0.155      0.877   -3227.844    2756.578
# people_fully_vaccinated_per_hundred    -1.2480      8.690     -0.144      0.886     -18.407      15.911
# extreme_poverty                         1.4705      7.814      0.188      0.851     -13.958      16.899
# people_vaccinated_per_hundred           1.8242      8.618      0.212      0.833     -15.193      18.842
# handwashing_facilities                 -2.1884      6.062     -0.361      0.719     -14.158       9.781
# North America                        -130.7220    344.439     -0.380      0.705    -810.829     549.385
# cardiovasc_death_rate                  -0.3724      0.975     -0.382      0.703      -2.297       1.552
# female_smokers                          6.1118     15.135      0.404      0.687     -23.773      35.997
# aged_65_older                         -37.1823     91.922     -0.404      0.686    -218.685     144.320
# male_smokers                           -4.0344      8.279     -0.487      0.627     -20.381      12.312
# Europe                                266.7323    459.581      0.580      0.562    -640.726    1174.191
# Asia                                  205.9107    344.950      0.597      0.551    -475.205     887.027
# tests_per_case                         -0.0058      0.007     -0.800      0.425      -0.020       0.008
# life_expectancy                       -23.5196     28.133     -0.836      0.404     -79.070      32.031
# population_density                     -0.1099      0.108     -1.019      0.309      -0.323       0.103
# Oceania                              -622.6496    497.583     -1.251      0.213   -1605.145     359.846
# median_age                            -47.5948     34.391     -1.384      0.168    -115.502      20.312
# South America                        -551.9816    367.717     -1.501      0.135   -1278.052     174.089
# hospital_beds_per_thousand            -78.7546     50.928     -1.546      0.124    -179.315      21.805
# aged_70_older                         216.1374    138.667      1.559      0.121     -57.665     489.940
# Africa                                597.0771    376.481      1.586      0.115    -146.299    1340.453
# diabetes_prevalence                    42.9846     26.190      1.641      0.103      -8.729      94.698
# human_development_index              3136.8895   1676.503      1.871      0.063    -173.423    6447.202
# total_boosters_per_hundred             17.8875      7.098      2.520      0.013       3.873      31.902
# new_tests_smoothed_per_thousand        29.8455      7.699      3.877      0.000      14.644      45.047
# positive_rate                        2897.4025    695.934      4.163      0.000    1523.257    4271.548
# ==============================================================================
# Omnibus:                       80.994   Durbin-Watson:                   2.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              295.475
# Skew:                           1.712   Prob(JB):                     6.89e-65
# Kurtosis:                       8.079   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.54e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 857729.866762497
# Removed ft:  gdp_per_capita
# Ft in use: ['people_fully_vaccinated_per_hundred', 'extreme_poverty', 'people_vaccinated_per_hundred', 'handwashing_facilities', 'North America', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.580
# Model:                               OLS   Adj. R-squared:                  0.522
# Method:                    Least Squares   F-statistic:                     9.922
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           6.29e-21
# Time:                           23:22:41   Log-Likelihood:                -1559.3
# No. Observations:                    189   AIC:                             3167.
# Df Residuals:                        165   BIC:                             3244.
# Df Model:                             23
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -208.9680   1499.512     -0.139      0.889   -3169.674    2751.738
# extreme_poverty                     1.3947      7.773      0.179      0.858     -13.952      16.742
# people_vaccinated_per_hundred       0.8856      5.602      0.158      0.875     -10.175      11.946
# handwashing_facilities             -2.2533      6.027     -0.374      0.709     -14.154       9.647
# North America                    -125.9755    341.831     -0.369      0.713    -800.902     548.951
# cardiovasc_death_rate              -0.3468      0.955     -0.363      0.717      -2.233       1.539
# female_smokers                      6.0700     15.088      0.402      0.688     -23.720      35.860
# aged_65_older                     -37.1414     91.648     -0.405      0.686    -218.096     143.813
# male_smokers                       -4.0773      8.249     -0.494      0.622     -20.364      12.209
# Europe                            277.9786    451.514      0.616      0.539    -613.511    1169.468
# Asia                              207.6656    343.709      0.604      0.547    -470.969     886.300
# tests_per_case                     -0.0058      0.007     -0.810      0.419      -0.020       0.008
# life_expectancy                   -23.8010     27.982     -0.851      0.396     -79.049      31.447
# population_density                 -0.1087      0.107     -1.014      0.312      -0.320       0.103
# Oceania                          -618.2329    495.156     -1.249      0.214   -1595.891     359.425
# median_age                        -47.8173     34.254     -1.396      0.165    -115.451      19.816
# South America                    -545.8799    364.169     -1.499      0.136   -1264.912     173.152
# hospital_beds_per_thousand        -78.6450     50.771     -1.549      0.123    -178.890      21.600
# aged_70_older                     216.0760    138.254      1.563      0.120     -56.899     489.051
# Africa                            595.4761    375.198      1.587      0.114    -145.332    1336.284
# diabetes_prevalence                42.7404     26.057      1.640      0.103      -8.708      94.189
# human_development_index          3127.9157   1670.358      1.873      0.063    -170.116    6425.947
# total_boosters_per_hundred         17.7417      7.004      2.533      0.012       3.913      31.570
# new_tests_smoothed_per_thousand    29.7576      7.652      3.889      0.000      14.650      44.865
# positive_rate                    2895.3274    693.716      4.174      0.000    1525.623    4265.031
# ==============================================================================
# Omnibus:                       80.693   Durbin-Watson:                   2.270
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              293.261
# Skew:                           1.706   Prob(JB):                     2.09e-64
# Kurtosis:                       8.059   Cond. No.                     1.12e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.67e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 857837.7329372173
# Removed ft:  people_fully_vaccinated_per_hundred
# Ft in use: ['extreme_poverty', 'people_vaccinated_per_hundred', 'handwashing_facilities', 'North America', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.580
# Model:                               OLS   Adj. R-squared:                  0.525
# Method:                    Least Squares   F-statistic:                     10.43
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.94e-21
# Time:                           23:22:41   Log-Likelihood:                -1559.3
# No. Observations:                    189   AIC:                             3165.
# Df Residuals:                        166   BIC:                             3239.
# Df Model:                             22
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -122.4751   1415.780     -0.087      0.931   -2917.731    2672.780
# people_vaccinated_per_hundred       0.8194      5.573      0.147      0.883     -10.185      11.823
# handwashing_facilities             -2.4993      5.852     -0.427      0.670     -14.053       9.055
# North America                    -111.5475    331.269     -0.337      0.737    -765.591     542.496
# cardiovasc_death_rate              -0.3634      0.948     -0.383      0.702      -2.235       1.509
# female_smokers                      6.2169     15.021      0.414      0.680     -23.441      35.874
# aged_65_older                     -37.1600     91.380     -0.407      0.685    -217.578     143.258
# male_smokers                       -4.1573      8.213     -0.506      0.613     -20.372      12.057
# Europe                            295.6984    439.296      0.673      0.502    -571.629    1163.026
# Asia                              219.7374    336.076      0.654      0.514    -443.798     883.273
# tests_per_case                     -0.0058      0.007     -0.812      0.418      -0.020       0.008
# life_expectancy                   -23.9215     27.892     -0.858      0.392     -78.990      31.147
# population_density                 -0.1072      0.107     -1.006      0.316      -0.318       0.103
# Oceania                          -610.0161    491.594     -1.241      0.216   -1580.599     360.567
# median_age                        -48.0349     34.133     -1.407      0.161    -115.426      19.356
# South America                    -537.9665    360.433     -1.493      0.137   -1249.591     173.658
# hospital_beds_per_thousand        -78.5155     50.618     -1.551      0.123    -178.454      21.423
# aged_70_older                     216.2319    137.848      1.569      0.119     -55.928     488.392
# Africa                            621.6190    344.745      1.803      0.073     -59.031    1302.270
# diabetes_prevalence                42.0557     25.701      1.636      0.104      -8.688      92.799
# human_development_index          3065.5426   1629.019      1.882      0.062    -150.724    6281.809
# total_boosters_per_hundred         17.7943      6.977      2.550      0.012       4.019      31.570
# new_tests_smoothed_per_thousand    29.8228      7.621      3.913      0.000      14.777      44.869
# positive_rate                    2899.1087    691.371      4.193      0.000    1534.094    4264.123
# ==============================================================================
# Omnibus:                       80.893   Durbin-Watson:                   2.271
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              294.773
# Skew:                           1.710   Prob(JB):                     9.79e-65
# Kurtosis:                       8.073   Cond. No.                     7.52e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.73e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 858005.1260041906
# Removed ft:  extreme_poverty
# Ft in use: ['people_vaccinated_per_hundred', 'handwashing_facilities', 'North America', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.580
# Model:                               OLS   Adj. R-squared:                  0.527
# Method:                    Least Squares   F-statistic:                     10.99
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           5.80e-22
# Time:                           23:22:41   Log-Likelihood:                -1559.3
# No. Observations:                    189   AIC:                             3163.
# Df Residuals:                        167   BIC:                             3234.
# Df Model:                             21
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -171.2071   1372.391     -0.125      0.901   -2880.678    2538.264
# handwashing_facilities             -2.6438      5.752     -0.460      0.646     -14.000       8.712
# North America                    -119.6060    325.744     -0.367      0.714    -762.713     523.501
# cardiovasc_death_rate              -0.3938      0.923     -0.427      0.670      -2.215       1.428
# female_smokers                      6.0021     14.906      0.403      0.688     -23.427      35.431
# aged_65_older                     -36.9579     91.102     -0.406      0.686    -216.818     142.902
# male_smokers                       -3.9347      8.048     -0.489      0.626     -19.824      11.954
# Europe                            286.5830    433.622      0.661      0.510    -569.505    1142.671
# Asia                              211.1635    330.007      0.640      0.523    -440.359     862.686
# tests_per_case                     -0.0058      0.007     -0.807      0.421      -0.020       0.008
# life_expectancy                   -23.1741     27.344     -0.847      0.398     -77.159      30.811
# population_density                 -0.1084      0.106     -1.023      0.308      -0.318       0.101
# Oceania                          -616.8515    487.955     -1.264      0.208   -1580.207     346.504
# median_age                        -46.9549     33.235     -1.413      0.160    -112.570      18.661
# South America                    -535.4330    358.965     -1.492      0.138   -1244.127     173.261
# hospital_beds_per_thousand        -79.0433     50.342     -1.570      0.118    -178.433      20.346
# aged_70_older                     214.5004    136.941      1.566      0.119     -55.857     484.858
# Africa                            602.9369    319.530      1.887      0.061     -27.901    1233.775
# diabetes_prevalence                41.6649     25.488      1.635      0.104      -8.656      91.986
# human_development_index          3117.0345   1586.254      1.965      0.051     -14.660    6248.729
# total_boosters_per_hundred         18.0306      6.770      2.663      0.008       4.665      31.396
# new_tests_smoothed_per_thousand    29.6877      7.543      3.936      0.000      14.796      44.579
# positive_rate                    2889.8702    686.490      4.210      0.000    1534.554    4245.187
# ==============================================================================
# Omnibus:                       81.035   Durbin-Watson:                   2.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              296.523
# Skew:                           1.711   Prob(JB):                     4.08e-65
# Kurtosis:                       8.093   Cond. No.                     2.39e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.68e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 858116.8391690116
# Removed ft:  people_vaccinated_per_hundred
# Ft in use: ['handwashing_facilities', 'North America', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.580
# Model:                               OLS   Adj. R-squared:                  0.530
# Method:                    Least Squares   F-statistic:                     11.59
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.84e-22
# Time:                           23:22:41   Log-Likelihood:                -1559.4
# No. Observations:                    189   AIC:                             3161.
# Df Residuals:                        168   BIC:                             3229.
# Df Model:                             20
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                             -83.3428   1355.819     -0.061      0.951   -2759.980    2593.294
# North America                    -148.9084    318.694     -0.467      0.641    -778.070     480.253
# cardiovasc_death_rate              -0.4357      0.916     -0.476      0.635      -2.244       1.372
# female_smokers                      6.3822     14.848      0.430      0.668     -22.931      35.696
# aged_65_older                     -35.7156     90.848     -0.393      0.695    -215.066     143.635
# male_smokers                       -4.3139      7.987     -0.540      0.590     -20.082      11.454
# Europe                            227.4790    413.145      0.551      0.583    -588.146    1043.104
# Asia                              209.3621    329.208      0.636      0.526    -440.555     859.279
# tests_per_case                     -0.0057      0.007     -0.802      0.423      -0.020       0.008
# life_expectancy                   -25.0497     26.974     -0.929      0.354     -78.302      28.203
# population_density                 -0.1026      0.105     -0.978      0.330      -0.310       0.105
# Oceania                          -518.1449    437.131     -1.185      0.238   -1381.122     344.833
# median_age                        -47.2450     33.151     -1.425      0.156    -112.692      18.202
# South America                    -533.8856    358.106     -1.491      0.138   -1240.852     173.081
# hospital_beds_per_thousand        -77.9112     50.164     -1.553      0.122    -176.944      21.122
# aged_70_older                     214.2493    136.618      1.568      0.119     -55.459     483.958
# Africa                            680.7549    270.355      2.518      0.013     147.024    1214.486
# diabetes_prevalence                41.2030     25.409      1.622      0.107      -8.958      91.364
# human_development_index          2967.0800   1548.695      1.916      0.057     -90.330    6024.490
# total_boosters_per_hundred         18.1584      6.748      2.691      0.008       4.837      31.480
# new_tests_smoothed_per_thousand    29.7200      7.525      3.950      0.000      14.865      44.575
# positive_rate                    2873.1606    683.915      4.201      0.000    1522.985    4223.336
# ==============================================================================
# Omnibus:                       81.257   Durbin-Watson:                   2.265
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              296.959
# Skew:                           1.718   Prob(JB):                     3.28e-65
# Kurtosis:                       8.090   Cond. No.                     8.72e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.78e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 859202.4567815489
# Removed ft:  handwashing_facilities
# Ft in use: ['North America', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.580
# Model:                               OLS   Adj. R-squared:                  0.530
# Method:                    Least Squares   F-statistic:                     11.59
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.84e-22
# Time:                           23:22:41   Log-Likelihood:                -1559.4
# No. Observations:                    189   AIC:                             3161.
# Df Residuals:                        168   BIC:                             3229.
# Df Model:                             20
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -232.2512   1603.238     -0.145      0.885   -3397.340    2932.838
# cardiovasc_death_rate              -0.4357      0.916     -0.476      0.635      -2.244       1.372
# female_smokers                      6.3822     14.848      0.430      0.668     -22.931      35.696
# aged_65_older                     -35.7156     90.848     -0.393      0.695    -215.066     143.635
# male_smokers                       -4.3139      7.987     -0.540      0.590     -20.082      11.454
# Europe                            376.3874    421.235      0.894      0.373    -455.209    1207.984
# Asia                              358.2705    312.290      1.147      0.253    -258.248     974.789
# tests_per_case                     -0.0057      0.007     -0.802      0.423      -0.020       0.008
# life_expectancy                   -25.0497     26.974     -0.929      0.354     -78.302      28.203
# population_density                 -0.1026      0.105     -0.978      0.330      -0.310       0.105
# Oceania                          -369.2365    465.566     -0.793      0.429   -1288.350     549.877
# median_age                        -47.2450     33.151     -1.425      0.156    -112.692      18.202
# South America                    -384.9772    374.995     -1.027      0.306   -1125.286     355.332
# hospital_beds_per_thousand        -77.9112     50.164     -1.553      0.122    -176.944      21.122
# aged_70_older                     214.2493    136.618      1.568      0.119     -55.459     483.958
# Africa                            829.6633    345.753      2.400      0.018     147.083    1512.244
# diabetes_prevalence                41.2030     25.409      1.622      0.107      -8.958      91.364
# human_development_index          2967.0800   1548.695      1.916      0.057     -90.330    6024.490
# total_boosters_per_hundred         18.1584      6.748      2.691      0.008       4.837      31.480
# new_tests_smoothed_per_thousand    29.7200      7.525      3.950      0.000      14.865      44.575
# positive_rate                    2873.1606    683.915      4.201      0.000    1522.985    4223.336
# ==============================================================================
# Omnibus:                       81.257   Durbin-Watson:                   2.265
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              296.959
# Skew:                           1.718   Prob(JB):                     3.28e-65
# Kurtosis:                       8.090   Cond. No.                     2.48e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.48e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 859202.4567815488
# Removed ft:  North America
# Ft in use: ['cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.579
# Model:                               OLS   Adj. R-squared:                  0.532
# Method:                    Least Squares   F-statistic:                     12.24
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           5.73e-23
# Time:                           23:22:41   Log-Likelihood:                -1559.5
# No. Observations:                    189   AIC:                             3159.
# Df Residuals:                        169   BIC:                             3224.
# Df Model:                             19
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -588.7699   1414.045     -0.416      0.678   -3380.237    2202.697
# female_smokers                      7.0519     14.748      0.478      0.633     -22.061      36.165
# aged_65_older                     -38.1899     90.491     -0.422      0.674    -216.828     140.449
# male_smokers                       -5.4027      7.634     -0.708      0.480     -20.474       9.668
# Europe                            334.8388    411.137      0.814      0.417    -476.787    1146.465
# Asia                              344.1317    310.160      1.110      0.269    -268.155     956.419
# tests_per_case                     -0.0055      0.007     -0.779      0.437      -0.020       0.008
# life_expectancy                   -21.8084     26.040     -0.837      0.403     -73.214      29.597
# population_density                 -0.1022      0.105     -0.976      0.330      -0.309       0.104
# Oceania                          -421.6997    451.279     -0.934      0.351   -1312.570     469.170
# median_age                        -48.4513     32.978     -1.469      0.144    -113.554      16.651
# South America                    -380.3236    374.008     -1.017      0.311   -1118.653     358.006
# hospital_beds_per_thousand        -82.8090     48.984     -1.691      0.093    -179.508      13.890
# aged_70_older                     220.6181    135.648      1.626      0.106     -47.166     488.402
# Africa                            847.8081    342.855      2.473      0.014     170.977    1524.639
# diabetes_prevalence                39.6380     25.137      1.577      0.117      -9.985      89.261
# human_development_index          3094.0098   1522.041      2.033      0.044      89.348    6098.672
# total_boosters_per_hundred         18.6752      6.645      2.810      0.006       5.558      31.793
# new_tests_smoothed_per_thousand    29.8062      7.505      3.971      0.000      14.990      44.623
# positive_rate                    2828.7269    675.955      4.185      0.000    1494.325    4163.129
# ==============================================================================
# Omnibus:                       80.873   Durbin-Watson:                   2.260
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              291.291
# Skew:                           1.715   Prob(JB):                     5.59e-64
# Kurtosis:                       8.022   Cond. No.                     2.44e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 860359.853584095
# Removed ft:  cardiovasc_death_rate
# Ft in use: ['female_smokers', 'aged_65_older', 'male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.579
# Model:                               OLS   Adj. R-squared:                  0.534
# Method:                    Least Squares   F-statistic:                     12.97
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.73e-23
# Time:                           23:22:41   Log-Likelihood:                -1559.7
# No. Observations:                    189   AIC:                             3157.
# Df Residuals:                        170   BIC:                             3219.
# Df Model:                             18
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -548.9077   1408.379     -0.390      0.697   -3329.072    2231.257
# aged_65_older                     -35.0012     90.040     -0.389      0.698    -212.742     142.739
# male_smokers                       -4.3572      7.298     -0.597      0.551     -18.763      10.049
# Europe                            409.6789    379.317      1.080      0.282    -339.100    1158.457
# Asia                              324.6244    306.767      1.058      0.291    -280.939     930.188
# tests_per_case                     -0.0058      0.007     -0.815      0.416      -0.020       0.008
# life_expectancy                   -22.3864     25.953     -0.863      0.390     -73.618      28.845
# population_density                 -0.1048      0.104     -1.004      0.317      -0.311       0.101
# Oceania                          -385.1444    443.746     -0.868      0.387   -1261.107     490.818
# median_age                        -50.5641     32.607     -1.551      0.123    -114.930      13.802
# South America                    -352.3165    368.554     -0.956      0.340   -1079.849     375.216
# hospital_beds_per_thousand        -84.0398     48.805     -1.722      0.087    -180.381      12.302
# aged_70_older                     224.7119    135.071      1.664      0.098     -41.920     491.343
# Africa                            834.7386    340.988      2.448      0.015     161.623    1507.854
# diabetes_prevalence                41.2857     24.843      1.662      0.098      -7.755      90.327
# human_development_index          3121.3429   1517.513      2.057      0.041     125.747    6116.938
# total_boosters_per_hundred         19.2227      6.531      2.944      0.004       6.331      32.114
# new_tests_smoothed_per_thousand    29.6412      7.480      3.963      0.000      14.875      44.408
# positive_rate                    2816.5462    673.940      4.179      0.000    1486.177    4146.915
# ==============================================================================
# Omnibus:                       80.045   Durbin-Watson:                   2.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              285.525
# Skew:                           1.700   Prob(JB):                     9.98e-63
# Kurtosis:                       7.970   Cond. No.                     2.43e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.43e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 861523.8763498394
# Removed ft:  female_smokers
# Ft in use: ['aged_65_older', 'male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.578
# Model:                               OLS   Adj. R-squared:                  0.536
# Method:                    Least Squares   F-statistic:                     13.79
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           4.91e-24
# Time:                           23:22:41   Log-Likelihood:                -1559.7
# No. Observations:                    189   AIC:                             3155.
# Df Residuals:                        171   BIC:                             3214.
# Df Model:                             17
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -579.2954   1402.714     -0.413      0.680   -3348.159    2189.569
# male_smokers                       -4.2516      7.275     -0.584      0.560     -18.611      10.108
# Europe                            395.5400    376.631      1.050      0.295    -347.905    1138.985
# Asia                              336.7035    304.431      1.106      0.270    -264.223     937.630
# tests_per_case                     -0.0062      0.007     -0.886      0.377      -0.020       0.008
# life_expectancy                   -21.6837     25.825     -0.840      0.402     -72.661      29.294
# population_density                 -0.1145      0.101     -1.134      0.258      -0.314       0.085
# Oceania                          -383.8698    442.632     -0.867      0.387   -1257.595     489.856
# median_age                        -51.0023     32.506     -1.569      0.118    -115.167      13.163
# South America                    -353.1600    367.632     -0.961      0.338   -1078.841     372.521
# hospital_beds_per_thousand        -84.3117     48.679     -1.732      0.085    -180.400      11.776
# aged_70_older                     177.4135     58.501      3.033      0.003      61.936     292.891
# Africa                            843.4278    339.409      2.485      0.014     173.457    1513.398
# diabetes_prevalence                40.7620     24.745      1.647      0.101      -8.083      89.607
# human_development_index          3053.7894   1503.783      2.031      0.044      85.421    6022.158
# total_boosters_per_hundred         19.2587      6.514      2.957      0.004       6.401      32.116
# new_tests_smoothed_per_thousand    29.9047      7.431      4.024      0.000      15.236      44.573
# positive_rate                    2816.2731    672.265      4.189      0.000    1489.267    4143.280
# ==============================================================================
# Omnibus:                       79.429   Durbin-Watson:                   2.257
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              281.289
# Skew:                           1.688   Prob(JB):                     8.30e-62
# Kurtosis:                       7.932   Cond. No.                     2.42e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.42e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 862289.6718839115
# Removed ft:  aged_65_older
# Ft in use: ['male_smokers', 'Europe', 'Asia', 'tests_per_case', 'life_expectancy', 'population_density', 'Oceania', 'median_age', 'South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.577
# Model:                               OLS   Adj. R-squared:                  0.538
# Method:                    Least Squares   F-statistic:                     14.68
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.47e-24
# Time:                           23:22:41   Log-Likelihood:                -1559.9
# No. Observations:                    189   AIC:                             3154.
# Df Residuals:                        172   BIC:                             3209.
# Df Model:                             16
# Covariance Type:               nonrobust
# ...
# Df Residuals:                        179   BIC:                             3182.
# Df Model:                              9
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1853.4822    617.163     -3.003      0.003   -3071.333    -635.631
# South America                    -486.5826    313.886     -1.550      0.123   -1105.975     132.810
# hospital_beds_per_thousand        -74.0569     44.145     -1.678      0.095    -161.168      13.054
# aged_70_older                     107.5601     32.351      3.325      0.001      43.722     171.398
# Africa                            888.7298    270.970      3.280      0.001     354.024    1423.435
# diabetes_prevalence                11.6138     21.734      0.534      0.594     -31.274      54.502
# human_development_index          1119.5472    997.944      1.122      0.263    -849.702    3088.796
# total_boosters_per_hundred         20.8094      5.955      3.494      0.001       9.058      32.561
# new_tests_smoothed_per_thousand    31.1037      6.898      4.509      0.000      17.491      44.716
# positive_rate                    3204.1407    621.718      5.154      0.000    1977.302    4430.980
# ==============================================================================
# Omnibus:                       72.732   Durbin-Watson:                   2.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              237.016
# Skew:                           1.563   Prob(JB):                     3.41e-52
# Kurtosis:                       7.508   Cond. No.                         476.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 910462.7908606193
# Removed ft:  median_age
# Ft in use: ['South America', 'hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.549
# Model:                               OLS   Adj. R-squared:                  0.529
# Method:                    Least Squares   F-statistic:                     27.35
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.78e-27
# Time:                           23:22:41   Log-Likelihood:                -1566.1
# No. Observations:                    189   AIC:                             3150.
# Df Residuals:                        180   BIC:                             3179.
# Df Model:                              8
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1856.0178    619.562     -2.996      0.003   -3078.556    -633.480
# hospital_beds_per_thousand        -65.6442     43.980     -1.493      0.137    -152.428      21.139
# aged_70_older                     114.1160     32.198      3.544      0.001      50.582     177.650
# Africa                            931.6651    270.599      3.443      0.001     397.711    1465.619
# diabetes_prevalence                15.7005     21.658      0.725      0.469     -27.035      58.436
# human_development_index           980.3168    997.760      0.983      0.327    -988.495    2949.129
# total_boosters_per_hundred         21.3231      5.969      3.572      0.000       9.545      33.102
# new_tests_smoothed_per_thousand    31.1647      6.925      4.500      0.000      17.500      44.829
# positive_rate                    2997.8740    609.675      4.917      0.000    1794.845    4200.903
# ==============================================================================
# Omnibus:                       76.937   Durbin-Watson:                   2.236
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              257.220
# Skew:                           1.655   Prob(JB):                     1.40e-56
# Kurtosis:                       7.659   Cond. No.                         475.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 922685.8257219418
# Removed ft:  South America
# Ft in use: ['hospital_beds_per_thousand', 'aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.543
# Model:                               OLS   Adj. R-squared:                  0.525
# Method:                    Least Squares   F-statistic:                     30.73
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           9.02e-28
# Time:                           23:22:41   Log-Likelihood:                -1567.3
# No. Observations:                    189   AIC:                             3151.
# Df Residuals:                        181   BIC:                             3177.
# Df Model:                              7
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1802.9731    620.636     -2.905      0.004   -3027.585    -578.361
# aged_70_older                      96.0003     29.924      3.208      0.002      36.956     155.044
# Africa                            944.7937    271.372      3.482      0.001     409.335    1480.252
# diabetes_prevalence                16.9376     21.715      0.780      0.436     -25.910      59.785
# human_development_index           747.8005    988.861      0.756      0.450   -1203.378    2698.979
# total_boosters_per_hundred         21.6853      5.984      3.624      0.000       9.877      33.493
# new_tests_smoothed_per_thousand    32.0603      6.922      4.631      0.000      18.401      45.719
# positive_rate                    3039.9501    611.085      4.975      0.000    1834.184    4245.716
# ==============================================================================
# Omnibus:                       81.774   Durbin-Watson:                   2.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              290.867
# Skew:                           1.745   Prob(JB):                     6.90e-64
# Kurtosis:                       7.976   Cond. No.                         468.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 934105.5313570024
# Removed ft:  hospital_beds_per_thousand
# Ft in use: ['aged_70_older', 'Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.517
# Model:                               OLS   Adj. R-squared:                  0.501
# Method:                    Least Squares   F-statistic:                     32.48
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           2.00e-26
# Time:                           23:22:41   Log-Likelihood:                -1572.5
# No. Observations:                    189   AIC:                             3159.
# Df Residuals:                        182   BIC:                             3182.
# Df Model:                              6
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -2529.5003    592.412     -4.270      0.000   -3698.379   -1360.622
# Africa                            940.5577    278.210      3.381      0.001     391.627    1489.489
# diabetes_prevalence                -9.9960     20.531     -0.487      0.627     -50.506      30.514
# human_development_index          2666.4622    807.366      3.303      0.001    1073.461    4259.463
# total_boosters_per_hundred         23.2512      6.115      3.802      0.000      11.186      35.316
# new_tests_smoothed_per_thousand    33.5488      7.081      4.738      0.000      19.578      47.520
# positive_rate                    3286.9689    621.498      5.289      0.000    2060.702    4513.236
# ==============================================================================
# Omnibus:                       77.121   Durbin-Watson:                   2.168
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              258.031
# Skew:                           1.659   Prob(JB):                     9.32e-57
# Kurtosis:                       7.664   Cond. No.                         386.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 987222.2296742249
# Removed ft:  aged_70_older
# Ft in use: ['Africa', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.487
# Model:                               OLS   Adj. R-squared:                  0.473
# Method:                    Least Squares   F-statistic:                     34.71
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           7.26e-25
# Time:                           23:22:41   Log-Likelihood:                -1578.3
# No. Observations:                    189   AIC:                             3169.
# Df Residuals:                        183   BIC:                             3188.
# Df Model:                              5
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1249.3480    468.400     -2.667      0.008   -2173.507    -325.188
# diabetes_prevalence               -38.0463     19.308     -1.970      0.050     -76.141       0.049
# human_development_index          2039.2320    807.841      2.524      0.012     445.353    3633.111
# total_boosters_per_hundred         15.8353      5.868      2.698      0.008       4.257      27.413
# new_tests_smoothed_per_thousand    33.1208      7.279      4.550      0.000      18.760      47.482
# positive_rate                    2395.3810    578.583      4.140      0.000    1253.830    3536.932
# ==============================================================================
# Omnibus:                       75.957   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              232.343
# Skew:                           1.678   Prob(JB):                     3.53e-51
# Kurtosis:                       7.272   Cond. No.                         369.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 1049219.1152853149
# Removed ft:  Africa
# Ft in use: ['diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.476
# Model:                               OLS   Adj. R-squared:                  0.464
# Method:                    Least Squares   F-statistic:                     41.76
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           6.93e-25
# Time:                           23:22:41   Log-Likelihood:                -1580.3
# No. Observations:                    189   AIC:                             3171.
# Df Residuals:                        184   BIC:                             3187.
# Df Model:                              4
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1333.5340    470.088     -2.837      0.005   -2260.989    -406.079
# human_development_index          1686.4498    793.900      2.124      0.035     120.133    3252.767
# total_boosters_per_hundred         16.5012      5.904      2.795      0.006       4.853      28.150
# new_tests_smoothed_per_thousand    33.5341      7.332      4.573      0.000      19.068      48.001
# positive_rate                    2493.7362    580.924      4.293      0.000    1347.607    3639.865
# ==============================================================================
# Omnibus:                       74.340   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              227.479
# Skew:                           1.636   Prob(JB):                     4.01e-50
# Kurtosis:                       7.264   Cond. No.                         357.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 1071481.3097604204
# Removed ft:  diabetes_prevalence
# Ft in use: ['human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# Break due to stopping rule: max pvalue = 0.03498381699620112 < 0.05

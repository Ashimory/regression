# %% [markdown]
# # Team members:
# - Nguyễn Duy Minh (myself)
# - Vũ Trường Giang
# - Vũ Hồng Phúc

# %%
import pandas as pd
import statsmodels.api as sm
import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv(r'./owid-2022-clean.csv')

# %%
# Drop irrelevant fields
print(df.columns.shape)
df.drop(["location", "date", "total_deaths_per_million", "total_cases_per_million", "population", "tests_units"], axis=1, inplace=True)

print(df.columns.shape)
# Out:
# (31,)
# (25,)

# %%
applied_cols = list(df.columns)
df_group_iso = df.groupby(["iso_code"])
df_group_cont = df.groupby(["continent"])

for col_name, col_data in df.iteritems():
    if col_name == "iso_code" or col_name=="continent":
        continue
    # replace nan with country median
    df[col_name] = df_group_iso[col_name].apply(lambda x: x.fillna(x.median()))
    # replace nan with continent median
    df[col_name] = df_group_cont[col_name].apply(lambda x: x.fillna(x.median()))

# Replace zeroes
df_group_cont_med = df_group_cont.median()
for col_name, col_data in df_group_iso:    
    for col in col_data:
        if (col_data[col] == 0).all():
            target = df.loc[df["iso_code"] == col_name]
            df.loc[df["iso_code"] == col_name, col] = target[col].replace(0, df_group_cont_med.at[target["continent"].iloc[0], col])

# %% [markdown]
#  # 1. Data preparations
#  - NaN/missing values are replaced with the median value of the country's other records.
#  - If all values are NaN/missing/zeros, replace them with the median value of the records from all countries within the same continent
#  - Only replace zero values when the entire column of the country is 0. This is because countries like Vietnam have days where no deaths are recorded, but other days still record a positive number. This is different to countries where no death numbers are recorded. There are cases where zero values may slightly raise some eyebrows, for example Albania recording no new cases in multiple days. However, they might as well be zero because "new_cases_per_million" mean some thing like "new_cases_reported_per_million" for example. Since our target variables are also based on reports, it may be best to simply also respect these reported zero values in other columns.
#  - A much better way to deal with these values (in my opinion) is to group countries by factors like GDP and poverty rate. However, it is more difficult and time consuming to do this since multiple factors need to be considered and the values are numeric instead of categorical. Since we have 6 deadlines this weekend, our team unfortunately had to abandon this approach for lack of time.

# %%
indicator_cols = pd.get_dummies(df[ "continent"])
df = pd.concat([df, indicator_cols], axis=1)
df.drop(["iso_code", "continent"], axis=1, inplace=True)

# %%
df.to_csv("./data.csv")

# %%
def linear_regression(X: pd.DataFrame, y: pd.DataFrame, ft_in_use, log = False):
    X = X[ft_in_use]

    model = sm.OLS(y, sm.add_constant(X))
    results = model.fit()

    if (log):
        print(results.summary())

    y_pred = results.predict(sm.add_constant(X))
    print(f'MSE: {sum((y - y_pred) ** 2) / len(y)}')
    return results

# %%
df = pd.read_csv('data.csv')

ft_predict = ['new_deaths_per_million', 'new_cases_per_million']
ft_ignore = ['iso_code', 'location', 'date', 'total_deaths', 'total_cases_per_million', 'total_deaths_per_million', 'population', 'tests_units'] # add ignore column names here

features = list(set(df.columns).difference(ft_predict + ft_ignore))

y = df[ft_predict]
X = df[features]

# %%
def new_deaths_per_million(X: pd.DataFrame, y: pd.DataFrame, ft_in_use):
    return linear_regression(X, y['new_deaths_per_million'], ft_in_use, log = True)

# %%
def new_cases_per_million(X: pd.DataFrame, y: pd.DataFrame, ft_in_use):
    return linear_regression(X, y['new_cases_per_million'], ft_in_use, log = True)

# %%
# ordinary linear regression

dth = new_deaths_per_million(X, y, features)
cas = new_cases_per_million(X, y, features)
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.227
# Method:                     Least Squares   F-statistic:                     15.42
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           8.56e-61
# Time:                            22:56:32   Log-Likelihood:                -3720.6
# No. Observations:                    1323   AIC:                             7497.
# Df Residuals:                        1295   BIC:                             7642.
# Df Model:                              27
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.6000      2.418     -2.316      0.021     -10.344      -0.856
# population_density                     -0.0001      0.000     -0.699      0.485      -0.000       0.000
# hospital_beds_per_thousand             -0.1546      0.079     -1.949      0.051      -0.310       0.001
# Unnamed: 0                              0.0005      0.000      1.586      0.113      -0.000       0.001
# people_vaccinated_per_hundred          -0.0092      0.014     -0.668      0.504      -0.036       0.018
# Asia                                   -1.4960      0.540     -2.769      0.006      -2.556      -0.436
# male_smokers                           -0.0032      0.013     -0.243      0.808      -0.029       0.023
# people_fully_vaccinated_per_hundred    -0.0163      0.014     -1.197      0.231      -0.043       0.010
# handwashing_facilities                  0.0069      0.010      0.723      0.470      -0.012       0.026
# gdp_per_capita                      -2.918e-05   1.13e-05     -2.586      0.010   -5.13e-05   -7.05e-06
# South America                           0.6428      0.593      1.084      0.279      -0.521       1.806
# stringency_index                        0.0033      0.008      0.420      0.674      -0.012       0.019
# new_tests_smoothed_per_thousand     -4.454e-05      0.012     -0.004      0.997      -0.023       0.023
# female_smokers                          0.1240      0.023      5.293      0.000       0.078       0.170
# total_boosters_per_hundred             -0.0293      0.012     -2.504      0.012      -0.052      -0.006
# cardiovasc_death_rate                   0.0017      0.002      1.143      0.253      -0.001       0.005
# Europe                                 -0.6895      0.712     -0.969      0.333      -2.086       0.707
# median_age                              0.1409      0.054      2.615      0.009       0.035       0.247
# extreme_poverty                         0.0046      0.012      0.373      0.709      -0.019       0.029
# life_expectancy                         0.0095      0.044      0.217      0.828      -0.076       0.095
# tests_per_case                       -3.85e-06   1.12e-05     -0.343      0.731   -2.59e-05    1.82e-05
# human_development_index                 5.2464      2.893      1.814      0.070      -0.429      10.922
# diabetes_prevalence                     0.0532      0.041      1.302      0.193      -0.027       0.133
# positive_rate                           0.6819      1.043      0.654      0.513      -1.364       2.727
# aged_70_older                          -0.0602      0.216     -0.279      0.780      -0.484       0.364
# Africa                                 -1.3333      0.584     -2.282      0.023      -2.479      -0.187
# aged_65_older                           0.0319      0.142      0.224      0.823      -0.248       0.311
# North America                          -0.1407      0.545     -0.258      0.796      -1.210       0.928
# Oceania                                -2.5834      0.821     -3.148      0.002      -4.193      -0.973
# ==============================================================================
# Omnibus:                     1746.748   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           465972.540
# Skew:                           6.967   Prob(JB):                         0.00
# Kurtosis:                      93.878   Cond. No.                     2.43e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.64e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 16.225021880629303
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.340
# Model:                               OLS   Adj. R-squared:                  0.326
# Method:                    Least Squares   F-statistic:                     24.67
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           2.68e-97
# Time:                           22:56:32   Log-Likelihood:                -11567.
# No. Observations:                   1323   AIC:                         2.319e+04
# Df Residuals:                       1295   BIC:                         2.334e+04
# Df Model:                             27
# Covariance Type:               nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                -222.0919    910.360     -0.244      0.807   -2008.034    1563.850
# population_density                     -0.1071      0.064     -1.675      0.094      -0.232       0.018
# hospital_beds_per_thousand            -81.3492     29.864     -2.724      0.007    -139.937     -22.761
# Unnamed: 0                             -0.1223      0.114     -1.069      0.285      -0.347       0.102
# people_vaccinated_per_hundred           1.4906      5.167      0.288      0.773      -8.646      11.627
# Asia                                  214.0269    203.402      1.052      0.293    -185.007     613.061
# male_smokers                           -3.7500      4.937     -0.760      0.448     -13.436       5.936
# people_fully_vaccinated_per_hundred    -1.0067      5.140     -0.196      0.845     -11.090       9.077
# handwashing_facilities                 -1.7921      3.588     -0.499      0.618      -8.832       5.247
# gdp_per_capita                       6.811e-05      0.004      0.016      0.987      -0.008       0.008
# South America                        -530.0734    223.254     -2.374      0.018    -968.052     -92.095
# stringency_index                       -0.2475      2.969     -0.083      0.934      -6.073       5.578
# new_tests_smoothed_per_thousand        28.2461      4.465      6.327      0.000      19.487      37.005
# female_smokers                          5.9063      8.822      0.669      0.503     -11.401      23.214
# total_boosters_per_hundred             17.6994      4.401      4.022      0.000       9.066      26.332
# cardiovasc_death_rate                  -0.3373      0.573     -0.589      0.556      -1.462       0.787
# Europe                                287.6193    267.963      1.073      0.283    -238.069     813.308
# median_age                            -49.2656     20.288     -2.428      0.015     -89.066      -9.465
# extreme_poverty                         1.9013      4.603      0.413      0.680      -7.128      10.931
# life_expectancy                       -22.6549     16.409     -1.381      0.168     -54.846       9.536
# tests_per_case                         -0.0060      0.004     -1.413      0.158      -0.014       0.002
# human_development_index              3234.6022   1089.117      2.970      0.003    1097.975    5371.229
# diabetes_prevalence                    43.4372     15.380      2.824      0.005      13.265      73.609
# positive_rate                        2705.5182    392.550      6.892      0.000    1935.414    3475.622
# aged_70_older                         221.5007     81.318      2.724      0.007      61.972     381.029
# Africa                                567.3466    219.923      2.580      0.010     135.903     998.790
# aged_65_older                         -39.2043     53.617     -0.731      0.465    -144.391      65.982
# North America                        -152.9736    205.171     -0.746      0.456    -555.477     249.530
# Oceania                              -608.0376    308.972     -1.968      0.049   -1214.178      -1.898
# ==============================================================================
# Omnibus:                     2056.316   Durbin-Watson:                   1.420
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1538446.064
# Skew:                           9.172   Prob(JB):                         0.00
# Kurtosis:                     169.048   Cond. No.                     2.43e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.64e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2299560.0547196222

# %%
# reorder columns according to p-values
# save to `features` variable

deaths_ft = sorted(features, key=lambda col: dth.pvalues[col])
cases_ft = sorted(features, key=lambda col: cas.pvalues[col])

alpha = 0.05

# %%
# stepwise forward regression

def forward_reg(title, features, func):
    if (title is not None):
        print(title)
    
    ft_in_use = []
    for col in features:
        ft_in_use.append(col)

        res = func(X, y, ft_in_use)

        print(f'Added ft:  {col}')
        print(f'Ft in use: {ft_in_use}')

        if (max(res.pvalues) > alpha):
            print(f'Break due to stopping rule: max pvalue = {max(res.pvalues)} > {alpha}')
            break

        print('*' * 20)

# %%
# stepwise forward regression
forward_reg('New deaths per million model:', deaths_ft, new_deaths_per_million)
# Out:
# New deaths per million model:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.146
# Model:                                OLS   Adj. R-squared:                  0.145
# Method:                     Least Squares   F-statistic:                     225.7
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           3.18e-47
# Time:                            22:56:33   Log-Likelihood:                -3800.6
# No. Observations:                    1323   AIC:                             7605.
# Df Residuals:                        1321   BIC:                             7616.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.6574      0.161      4.091      0.000       0.342       0.973
# female_smokers     0.1797      0.012     15.025      0.000       0.156       0.203
# ==============================================================================
# Omnibus:                     1717.771   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           399469.470
# Skew:                           6.804   Prob(JB):                         0.00
# Kurtosis:                      87.032   Cond. No.                         18.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 18.311585328677488
# Added ft:  female_smokers
# Ft in use: ['female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.159
# Model:                                OLS   Adj. R-squared:                  0.158
# Method:                     Least Squares   F-statistic:                     125.2
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.67e-50
# Time:                            22:56:33   Log-Likelihood:                -3790.1
# No. Observations:                    1323   AIC:                             7586.
# Df Residuals:                        1320   BIC:                             7602.
# Df Model:                               2
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.7021      0.160      4.394      0.000       0.389       1.016
# female_smokers     0.1881      0.012     15.662      0.000       0.165       0.212
# Oceania           -2.5531      0.555     -4.599      0.000      -3.642      -1.464
# ==============================================================================
# Omnibus:                     1735.816   Durbin-Watson:                   1.743
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           419992.593
# Skew:                           6.927   Prob(JB):                         0.00
# Kurtosis:                      89.180   Cond. No.                         63.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 18.022820284582576
# Added ft:  Oceania
# Ft in use: ['female_smokers', 'Oceania']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.164
# Model:                                OLS   Adj. R-squared:                  0.162
# Method:                     Least Squares   F-statistic:                     86.11
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           6.93e-51
# Time:                            22:56:33   Log-Likelihood:                -3786.6
# No. Observations:                    1323   AIC:                             7581.
# Df Residuals:                        1319   BIC:                             7602.
# Df Model:                               3
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.9706      0.189      5.124      0.000       0.599       1.342
# female_smokers     0.1796      0.012     14.460      0.000       0.155       0.204
# Oceania           -2.6861      0.556     -4.829      0.000      -3.777      -1.595
# Asia              -0.7398      0.282     -2.625      0.009      -1.293      -0.187
# ==============================================================================
# Omnibus:                     1730.985   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           416510.187
# Skew:                           6.891   Prob(JB):                         0.00
# Kurtosis:                      88.824   Cond. No.                         64.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 17.929180470889985
# Added ft:  Asia
# Ft in use: ['female_smokers', 'Oceania', 'Asia']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.187
# Model:                                OLS   Adj. R-squared:                  0.184
# Method:                     Least Squares   F-statistic:                     75.57
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           9.91e-58
# Time:                            22:56:33   Log-Likelihood:                -3768.4
# No. Observations:                    1323   AIC:                             7547.
# Df Residuals:                        1318   BIC:                             7573.
# Df Model:                               4
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -1.5506      0.455     -3.407      0.001      -2.443      -0.658
# female_smokers     0.1083      0.017      6.381      0.000       0.075       0.142
# Oceania           -1.8570      0.566     -3.284      0.001      -2.966      -0.748
# Asia              -1.1500      0.286     -4.019      0.000      -1.711      -0.589
# median_age         0.1065      0.018      6.076      0.000       0.072       0.141
# ==============================================================================
# Omnibus:                     1740.043   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           434907.791
# Skew:                           6.945   Prob(JB):                         0.00
# Kurtosis:                      90.730   Cond. No.                         173.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 17.440715882382097
# Added ft:  median_age
# Ft in use: ['female_smokers', 'Oceania', 'Asia', 'median_age']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.201
# Model:                                OLS   Adj. R-squared:                  0.198
# Method:                     Least Squares   F-statistic:                     66.16
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           9.57e-62
# Time:                            22:56:33   Log-Likelihood:                -3756.7
# No. Observations:                    1323   AIC:                             7525.
# Df Residuals:                        1317   BIC:                             7557.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -2.4720      0.490     -5.046      0.000      -3.433      -1.511
# female_smokers     0.1049      0.017      6.231      0.000       0.072       0.138
# Oceania           -1.8232      0.561     -3.251      0.001      -2.923      -0.723
# Asia              -0.9936      0.286     -3.479      0.001      -1.554      -0.433
# median_age         0.1594      0.021      7.760      0.000       0.119       0.200
# gdp_per_capita -3.698e-05   7.65e-06     -4.834      0.000    -5.2e-05    -2.2e-05
# ==============================================================================
# Omnibus:                     1760.878   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           466331.335
# Skew:                           7.083   Prob(JB):                         0.00
# Kurtosis:                      93.878   Cond. No.                     1.41e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 17.136655261058618
# Added ft:  gdp_per_capita
# Ft in use: ['female_smokers', 'Oceania', 'Asia', 'median_age', 'gdp_per_capita']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.208
# Model:                                OLS   Adj. R-squared:                  0.204
# Method:                     Least Squares   F-statistic:                     57.56
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           2.40e-63
# Time:                            22:56:33   Log-Likelihood:                -3750.8
# No. Observations:                    1323   AIC:                             7516.
# Df Residuals:                        1316   BIC:                             7552.
# Df Model:                               6
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -2.7167      0.493     -5.510      0.000      -3.684      -1.749
# female_smokers                 0.1283      0.018      7.091      0.000       0.093       0.164
# Oceania                       -1.3520      0.575     -2.351      0.019      -2.480      -0.224
# Asia                          -0.6698      0.300     -2.236      0.026      -1.258      -0.082
# median_age                     0.1717      0.021      8.269      0.000       0.131       0.212
# gdp_per_capita             -2.532e-05   8.34e-06     -3.038      0.002   -4.17e-05   -8.97e-06
# total_boosters_per_hundred    -0.0334      0.010     -3.445      0.001      -0.052      -0.014
# ==============================================================================
# Omnibus:                     1752.327   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           459649.949
# Skew:                           7.019   Prob(JB):                         0.00
# Kurtosis:                      93.229   Cond. No.                     1.46e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.98351650143205
# Added ft:  total_boosters_per_hundred
# Ft in use: ['female_smokers', 'Oceania', 'Asia', 'median_age', 'gdp_per_capita', 'total_boosters_per_hundred']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.226
# Model:                                OLS   Adj. R-squared:                  0.222
# Method:                     Least Squares   F-statistic:                     54.92
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           4.81e-69
# Time:                            22:56:33   Log-Likelihood:                -3735.3
# No. Observations:                    1323   AIC:                             7487.
# Df Residuals:                        1315   BIC:                             7528.
# Df Model:                               7
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.2993      0.728      0.411      0.681      -1.128       1.727
# female_smokers                 0.1192      0.018      6.640      0.000       0.084       0.154
# Oceania                       -2.2639      0.592     -3.827      0.000      -3.424      -1.103
# Asia                          -1.6092      0.341     -4.724      0.000      -2.277      -0.941
# median_age                     0.1116      0.023      4.814      0.000       0.066       0.157
# gdp_per_capita             -1.932e-05   8.31e-06     -2.324      0.020   -3.56e-05   -3.01e-06
# total_boosters_per_hundred    -0.0473      0.010     -4.773      0.000      -0.067      -0.028
# Africa                        -2.3356      0.418     -5.582      0.000      -3.156      -1.515
# ==============================================================================
# Omnibus:                     1735.116   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           442604.576
# Skew:                           6.896   Prob(JB):                         0.00
# Kurtosis:                      91.538   Cond. No.                     2.09e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.590356933467177
# Added ft:  Africa
# Ft in use: ['female_smokers', 'Oceania', 'Asia', 'median_age', 'gdp_per_capita', 'total_boosters_per_hundred', 'Africa']
# Break due to stopping rule: max pvalue = 0.6808968136560637 > 0.05

# %%
forward_reg('New cases per million model:', cases_ft, new_cases_per_million)
# Out:
# New cases per million model:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.111
# Model:                               OLS   Adj. R-squared:                  0.110
# Method:                    Least Squares   F-statistic:                     164.8
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.22e-35
# Time:                           22:56:33   Log-Likelihood:                -11764.
# No. Observations:                   1323   AIC:                         2.353e+04
# Df Residuals:                       1321   BIC:                         2.354e+04
# Df Model:                              1
# Covariance Type:               nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           111.2212     78.109      1.424      0.155     -42.011     264.453
# positive_rate  3789.5340    295.157     12.839      0.000    3210.507    4368.561
# ==============================================================================
# Omnibus:                     1713.665   Durbin-Watson:                   1.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           468113.420
# Skew:                           6.696   Prob(JB):                         0.00
# Kurtosis:                      94.173   Cond. No.                         6.37
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE: 3095930.921515806
# Added ft:  positive_rate
# Ft in use: ['positive_rate']
# Break due to stopping rule: max pvalue = 0.15470730705019203 > 0.05

# %%
# stepwise backward regression

def backward_reg(title, features, func):
    if (title is not None):
        print(title)
    
    features.reverse()
    ft_in_use = features.copy()
    for col in features:
        ft_in_use.remove(col)

        res = func(X, y, ft_in_use)

        print(f'Removed ft:  {col}')
        print(f'Ft in use: {ft_in_use}')

        if (max(res.pvalues) < alpha):
            print(f'Break due to stopping rule: max pvalue = {max(res.pvalues)} < {alpha}')
            break

        print('*' * 20)

# %%
# stepwise backward regression
backward_reg('New deaths per million model:', deaths_ft, new_deaths_per_million)
# Out:
# New deaths per million model:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.228
# Method:                     Least Squares   F-statistic:                     16.02
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           2.11e-61
# Time:                            22:56:33   Log-Likelihood:                -3720.6
# No. Observations:                    1323   AIC:                             7495.
# Df Residuals:                        1296   BIC:                             7635.
# Df Model:                              26
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.5995      2.414     -2.320      0.020     -10.334      -0.865
# life_expectancy                         0.0095      0.044      0.217      0.828      -0.076       0.095
# aged_65_older                           0.0319      0.142      0.225      0.822      -0.246       0.310
# male_smokers                           -0.0032      0.013     -0.247      0.805      -0.029       0.022
# North America                          -0.1405      0.543     -0.259      0.796      -1.206       0.925
# aged_70_older                          -0.0603      0.215     -0.280      0.779      -0.482       0.362
# tests_per_case                      -3.853e-06   1.12e-05     -0.344      0.731   -2.58e-05    1.81e-05
# extreme_poverty                         0.0046      0.012      0.374      0.709      -0.019       0.029
# stringency_index                        0.0033      0.008      0.420      0.674      -0.012       0.019
# positive_rate                           0.6833      0.972      0.703      0.482      -1.224       2.590
# people_vaccinated_per_hundred          -0.0092      0.014     -0.674      0.500      -0.036       0.018
# population_density                     -0.0001      0.000     -0.717      0.474      -0.000       0.000
# handwashing_facilities                  0.0069      0.010      0.724      0.469      -0.012       0.026
# Europe                                 -0.6900      0.701     -0.984      0.325      -2.066       0.686
# South America                           0.6427      0.592      1.085      0.278      -0.519       1.805
# cardiovasc_death_rate                   0.0017      0.002      1.144      0.253      -0.001       0.005
# people_fully_vaccinated_per_hundred    -0.0164      0.014     -1.202      0.229      -0.043       0.010
# diabetes_prevalence                     0.0532      0.041      1.304      0.192      -0.027       0.133
# Unnamed: 0                              0.0005      0.000      1.592      0.112      -0.000       0.001
# human_development_index                 5.2446      2.850      1.840      0.066      -0.347      10.836
# hospital_beds_per_thousand             -0.1546      0.079     -1.962      0.050      -0.309    1.24e-05
# Africa                                 -1.3329      0.576     -2.314      0.021      -2.463      -0.203
# total_boosters_per_hundred             -0.0293      0.012     -2.537      0.011      -0.052      -0.007
# gdp_per_capita                      -2.918e-05   1.13e-05     -2.588      0.010   -5.13e-05   -7.06e-06
# median_age                              0.1410      0.054      2.626      0.009       0.036       0.246
# Asia                                   -1.4958      0.538     -2.778      0.006      -2.552      -0.440
# Oceania                                -2.5830      0.814     -3.171      0.002      -4.181      -0.985
# female_smokers                          0.1240      0.023      5.305      0.000       0.078       0.170
# ==============================================================================
# Omnibus:                     1746.746   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           465966.004
# Skew:                           6.967   Prob(JB):                         0.00
# Kurtosis:                      93.878   Cond. No.                     2.43e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.64e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 16.225022057349094
# Removed ft:  new_tests_smoothed_per_thousand
# Ft in use: ['life_expectancy', 'aged_65_older', 'male_smokers', 'North America', 'aged_70_older', 'tests_per_case', 'extreme_poverty', 'stringency_index', 'positive_rate', 'people_vaccinated_per_hundred', 'population_density', 'handwashing_facilities', 'Europe', 'South America', 'cardiovasc_death_rate', 'people_fully_vaccinated_per_hundred', 'diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.229
# Method:                     Least Squares   F-statistic:                     16.68
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           5.22e-62
# Time:                            22:56:33   Log-Likelihood:                -3720.6
# No. Observations:                    1323   AIC:                             7493.
# Df Residuals:                        1297   BIC:                             7628.
# Df Model:                              25
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.1798      1.447     -3.580      0.000      -8.018      -2.341
# aged_65_older                           0.0305      0.142      0.215      0.830      -0.247       0.308
# male_smokers                           -0.0033      0.013     -0.256      0.798      -0.029       0.022
# North America                          -0.0693      0.433     -0.160      0.873      -0.918       0.780
# aged_70_older                          -0.0553      0.214     -0.259      0.796      -0.475       0.364
# tests_per_case                      -3.858e-06   1.12e-05     -0.345      0.730   -2.58e-05    1.81e-05
# extreme_poverty                         0.0045      0.012      0.369      0.712      -0.019       0.028
# stringency_index                        0.0032      0.008      0.410      0.682      -0.012       0.019
# positive_rate                           0.7095      0.964      0.736      0.462      -1.182       2.601
# people_vaccinated_per_hundred          -0.0090      0.014     -0.661      0.508      -0.036       0.018
# population_density                     -0.0001      0.000     -0.698      0.485      -0.000       0.000
# handwashing_facilities                  0.0072      0.009      0.768      0.443      -0.011       0.026
# Europe                                 -0.6295      0.644     -0.978      0.328      -1.892       0.633
# South America                           0.7046      0.519      1.358      0.175      -0.314       1.723
# cardiovasc_death_rate                   0.0017      0.001      1.124      0.261      -0.001       0.005
# people_fully_vaccinated_per_hundred    -0.0162      0.014     -1.191      0.234      -0.043       0.010
# diabetes_prevalence                     0.0545      0.040      1.351      0.177      -0.025       0.134
# Unnamed: 0                              0.0005      0.000      1.592      0.112      -0.000       0.001
# human_development_index                 5.4398      2.704      2.012      0.044       0.135      10.745
# hospital_beds_per_thousand             -0.1569      0.078     -2.011      0.044      -0.310      -0.004
# Africa                                 -1.2702      0.498     -2.550      0.011      -2.247      -0.293
# total_boosters_per_hundred             -0.0292      0.012     -2.532      0.011      -0.052      -0.007
# gdp_per_capita                      -2.924e-05   1.13e-05     -2.594      0.010   -5.13e-05   -7.12e-06
# median_age                              0.1417      0.054      2.647      0.008       0.037       0.247
# Asia                                   -1.4187      0.405     -3.506      0.000      -2.213      -0.625
# Oceania                                -2.4968      0.711     -3.512      0.000      -3.892      -1.102
# female_smokers                          0.1238      0.023      5.303      0.000       0.078       0.170
# ==============================================================================
# Omnibus:                     1746.727   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           465696.045
# Skew:                           6.967   Prob(JB):                         0.00
# Kurtosis:                      93.851   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.64e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 16.22561318090926
# Removed ft:  life_expectancy
# Ft in use: ['aged_65_older', 'male_smokers', 'North America', 'aged_70_older', 'tests_per_case', 'extreme_poverty', 'stringency_index', 'positive_rate', 'people_vaccinated_per_hundred', 'population_density', 'handwashing_facilities', 'Europe', 'South America', 'cardiovasc_death_rate', 'people_fully_vaccinated_per_hundred', 'diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.229
# Method:                     Least Squares   F-statistic:                     17.38
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.26e-62
# Time:                            22:56:33   Log-Likelihood:                -3720.6
# No. Observations:                    1323   AIC:                             7491.
# Df Residuals:                        1298   BIC:                             7621.
# Df Model:                              24
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.1936      1.445     -3.594      0.000      -8.028      -2.359
# male_smokers                           -0.0035      0.013     -0.275      0.783      -0.029       0.022
# North America                          -0.0675      0.433     -0.156      0.876      -0.916       0.781
# aged_70_older                          -0.0147      0.100     -0.147      0.883      -0.211       0.182
# tests_per_case                      -3.505e-06   1.11e-05     -0.317      0.751   -2.52e-05    1.82e-05
# extreme_poverty                         0.0045      0.012      0.369      0.712      -0.019       0.028
# stringency_index                        0.0033      0.008      0.418      0.676      -0.012       0.019
# positive_rate                           0.7153      0.963      0.742      0.458      -1.175       2.605
# people_vaccinated_per_hundred          -0.0089      0.014     -0.659      0.510      -0.036       0.018
# population_density                     -0.0001      0.000     -0.668      0.504      -0.000       0.000
# handwashing_facilities                  0.0071      0.009      0.761      0.447      -0.011       0.026
# Europe                                 -0.6224      0.642     -0.969      0.333      -1.883       0.638
# South America                           0.7036      0.519      1.356      0.175      -0.314       1.721
# cardiovasc_death_rate                   0.0017      0.001      1.143      0.253      -0.001       0.005
# people_fully_vaccinated_per_hundred    -0.0162      0.014     -1.193      0.233      -0.043       0.010
# diabetes_prevalence                     0.0547      0.040      1.358      0.175      -0.024       0.134
# Unnamed: 0                              0.0005      0.000      1.590      0.112      -0.000       0.001
# human_development_index                 5.4883      2.694      2.037      0.042       0.204      10.773
# hospital_beds_per_thousand             -0.1565      0.078     -2.008      0.045      -0.310      -0.004
# Africa                                 -1.2750      0.497     -2.563      0.010      -2.251      -0.299
# total_boosters_per_hundred             -0.0292      0.012     -2.538      0.011      -0.052      -0.007
# gdp_per_capita                      -2.927e-05   1.13e-05     -2.598      0.009   -5.14e-05   -7.17e-06
# median_age                              0.1422      0.053      2.659      0.008       0.037       0.247
# Asia                                   -1.4280      0.402     -3.550      0.000      -2.217      -0.639
# Oceania                                -2.5043      0.710     -3.528      0.000      -3.897      -1.112
# female_smokers                          0.1243      0.023      5.342      0.000       0.079       0.170
# ==============================================================================
# Omnibus:                     1746.410   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           465153.952
# Skew:                           6.965   Prob(JB):                         0.00
# Kurtosis:                      93.797   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.63e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 16.226192703503738
# Removed ft:  aged_65_older
# Ft in use: ['male_smokers', 'North America', 'aged_70_older', 'tests_per_case', 'extreme_poverty', 'stringency_index', 'positive_rate', 'people_vaccinated_per_hundred', 'population_density', 'handwashing_facilities', 'Europe', 'South America', 'cardiovasc_death_rate', 'people_fully_vaccinated_per_hundred', 'diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.230
# Method:                     Least Squares   F-statistic:                     18.15
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           3.03e-63
# Time:                            22:56:33   Log-Likelihood:                -3720.6
# No. Observations:                    1323   AIC:                             7489.
# Df Residuals:                        1299   BIC:                             7614.
# Df Model:                              23
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.2000      1.444     -3.600      0.000      -8.033      -2.367
# North America                          -0.0449      0.425     -0.106      0.916      -0.878       0.788
# aged_70_older                          -0.0120      0.100     -0.120      0.904      -0.208       0.184
# tests_per_case                      -3.595e-06   1.11e-05     -0.325      0.745   -2.53e-05    1.81e-05
# extreme_poverty                         0.0046      0.012      0.375      0.708      -0.019       0.028
# stringency_index                        0.0032      0.008      0.403      0.687      -0.012       0.019
# positive_rate                           0.6998      0.961      0.728      0.467      -1.186       2.586
# people_vaccinated_per_hundred          -0.0090      0.014     -0.665      0.506      -0.036       0.018
# population_density                     -0.0001      0.000     -0.688      0.492      -0.000       0.000
# handwashing_facilities                  0.0070      0.009      0.743      0.457      -0.011       0.025
# Europe                                 -0.6181      0.642     -0.963      0.336      -1.878       0.641
# South America                           0.7265      0.512      1.419      0.156      -0.278       1.731
# cardiovasc_death_rate                   0.0016      0.001      1.110      0.267      -0.001       0.004
# people_fully_vaccinated_per_hundred    -0.0165      0.014     -1.218      0.224      -0.043       0.010
# diabetes_prevalence                     0.0536      0.040      1.338      0.181      -0.025       0.132
# Unnamed: 0                              0.0005      0.000      1.594      0.111      -0.000       0.001
# human_development_index                 5.5120      2.691      2.048      0.041       0.232      10.792
# hospital_beds_per_thousand             -0.1600      0.077     -2.079      0.038      -0.311      -0.009
# Africa                                 -1.2962      0.491     -2.638      0.008      -2.260      -0.332
# total_boosters_per_hundred             -0.0292      0.012     -2.537      0.011      -0.052      -0.007
# gdp_per_capita                      -2.862e-05    1.1e-05     -2.600      0.009   -5.02e-05   -7.02e-06
# median_age                              0.1409      0.053      2.646      0.008       0.036       0.245
# Asia                                   -1.4614      0.383     -3.812      0.000      -2.213      -0.709
# Oceania                                -2.5060      0.710     -3.531      0.000      -3.898      -1.114
# female_smokers                          0.1223      0.022      5.514      0.000       0.079       0.166
# ==============================================================================
# Omnibus:                     1746.480   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           465249.667
# Skew:                           6.965   Prob(JB):                         0.00
# Kurtosis:                      93.807   Cond. No.                     1.96e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.54e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 16.227140756274206
# Removed ft:  male_smokers
# Ft in use: ['North America', 'aged_70_older', 'tests_per_case', 'extreme_poverty', 'stringency_index', 'positive_rate', 'people_vaccinated_per_hundred', 'population_density', 'handwashing_facilities', 'Europe', 'South America', 'cardiovasc_death_rate', 'people_fully_vaccinated_per_hundred', 'diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.230
# Method:                     Least Squares   F-statistic:                     18.15
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           3.03e-63
# Time:                            22:56:33   Log-Likelihood:                -3720.6
# No. Observations:                    1323   AIC:                             7489.
# Df Residuals:                        1299   BIC:                             7614.
# Df Model:                              23
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.2449      1.693     -3.098      0.002      -8.566      -1.923
# aged_70_older                          -0.0120      0.100     -0.120      0.904      -0.208       0.184
# tests_per_case                      -3.595e-06   1.11e-05     -0.325      0.745   -2.53e-05    1.81e-05
# extreme_poverty                         0.0046      0.012      0.375      0.708      -0.019       0.028
# stringency_index                        0.0032      0.008      0.403      0.687      -0.012       0.019
# positive_rate                           0.6998      0.961      0.728      0.467      -1.186       2.586
# people_vaccinated_per_hundred          -0.0090      0.014     -0.665      0.506      -0.036       0.018
# population_density                     -0.0001      0.000     -0.688      0.492      -0.000       0.000
# handwashing_facilities                  0.0070      0.009      0.743      0.457      -0.011       0.025
# Europe                                 -0.5732      0.657     -0.873      0.383      -1.862       0.715
# South America                           0.7714      0.608      1.268      0.205      -0.422       1.965
# cardiovasc_death_rate                   0.0016      0.001      1.110      0.267      -0.001       0.004
# people_fully_vaccinated_per_hundred    -0.0165      0.014     -1.218      0.224      -0.043       0.010
# diabetes_prevalence                     0.0536      0.040      1.338      0.181      -0.025       0.132
# Unnamed: 0                              0.0005      0.000      1.594      0.111      -0.000       0.001
# human_development_index                 5.5120      2.691      2.048      0.041       0.232      10.792
# hospital_beds_per_thousand             -0.1600      0.077     -2.079      0.038      -0.311      -0.009
# Africa                                 -1.2513      0.651     -1.923      0.055      -2.528       0.025
# total_boosters_per_hundred             -0.0292      0.012     -2.537      0.011      -0.052      -0.007
# gdp_per_capita                      -2.862e-05    1.1e-05     -2.600      0.009   -5.02e-05   -7.02e-06
# median_age                              0.1409      0.053      2.646      0.008       0.036       0.245
# Asia                                   -1.4166      0.469     -3.021      0.003      -2.336      -0.497
# Oceania                                -2.4611      0.885     -2.780      0.006      -4.198      -0.725
# female_smokers                          0.1223      0.022      5.514      0.000       0.079       0.166
# ==============================================================================
# Omnibus:                     1746.480   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           465249.667
# Skew:                           6.965   Prob(JB):                         0.00
# Kurtosis:                      93.807   Cond. No.                     7.16e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.16e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.227140756274164
# Removed ft:  North America
# Ft in use: ['aged_70_older', 'tests_per_case', 'extreme_poverty', 'stringency_index', 'positive_rate', 'people_vaccinated_per_hundred', 'population_density', 'handwashing_facilities', 'Europe', 'South America', 'cardiovasc_death_rate', 'people_fully_vaccinated_per_hundred', 'diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.230
# Method:                     Least Squares   F-statistic:                     18.98
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           6.91e-64
# Time:                            22:56:33   Log-Likelihood:                -3720.7
# No. Observations:                    1323   AIC:                             7487.
# Df Residuals:                        1300   BIC:                             7607.
# Df Model:                              22
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.1998      1.650     -3.151      0.002      -8.437      -1.962
# tests_per_case                      -3.491e-06    1.1e-05     -0.317      0.751   -2.51e-05    1.81e-05
# extreme_poverty                         0.0045      0.012      0.370      0.711      -0.019       0.028
# stringency_index                        0.0032      0.008      0.406      0.685      -0.012       0.019
# positive_rate                           0.6843      0.952      0.719      0.473      -1.184       2.553
# people_vaccinated_per_hundred          -0.0088      0.013     -0.655      0.513      -0.035       0.018
# population_density                     -0.0001      0.000     -0.694      0.488      -0.000       0.000
# handwashing_facilities                  0.0071      0.009      0.757      0.449      -0.011       0.025
# Europe                                 -0.5813      0.653     -0.890      0.374      -1.863       0.700
# South America                           0.7809      0.603      1.295      0.195      -0.402       1.964
# cardiovasc_death_rate                   0.0016      0.001      1.167      0.243      -0.001       0.004
# people_fully_vaccinated_per_hundred    -0.0165      0.014     -1.222      0.222      -0.043       0.010
# diabetes_prevalence                     0.0554      0.037      1.489      0.137      -0.018       0.128
# Unnamed: 0                              0.0005      0.000      1.592      0.112      -0.000       0.001
# human_development_index                 5.5050      2.690      2.047      0.041       0.228      10.782
# hospital_beds_per_thousand             -0.1614      0.076     -2.122      0.034      -0.311      -0.012
# Africa                                 -1.2447      0.648     -1.921      0.055      -2.516       0.027
# total_boosters_per_hundred             -0.0294      0.011     -2.565      0.010      -0.052      -0.007
# gdp_per_capita                      -2.829e-05   1.07e-05     -2.651      0.008   -4.92e-05   -7.36e-06
# median_age                              0.1363      0.037      3.687      0.000       0.064       0.209
# Asia                                   -1.4041      0.457     -3.071      0.002      -2.301      -0.507
# Oceania                                -2.4683      0.883     -2.796      0.005      -4.200      -0.736
# female_smokers                          0.1218      0.022      5.626      0.000       0.079       0.164
# ==============================================================================
# Omnibus:                     1746.807   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           465525.278
# Skew:                           6.968   Prob(JB):                         0.00
# Kurtosis:                      93.833   Cond. No.                     7.14e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.14e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.227321356509616
# Removed ft:  aged_70_older
# Ft in use: ['tests_per_case', 'extreme_poverty', 'stringency_index', 'positive_rate', 'people_vaccinated_per_hundred', 'population_density', 'handwashing_facilities', 'Europe', 'South America', 'cardiovasc_death_rate', 'people_fully_vaccinated_per_hundred', 'diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.231
# Method:                     Least Squares   F-statistic:                     19.90
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.60e-64
# Time:                            22:56:33   Log-Likelihood:                -3720.7
# No. Observations:                    1323   AIC:                             7485.
# Df Residuals:                        1301   BIC:                             7600.
# Df Model:                              21
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.1962      1.650     -3.150      0.002      -8.433      -1.960
# extreme_poverty                         0.0045      0.012      0.366      0.714      -0.019       0.028
# stringency_index                        0.0031      0.008      0.393      0.695      -0.012       0.018
# positive_rate                           0.6741      0.951      0.708      0.479      -1.193       2.541
# people_vaccinated_per_hundred          -0.0087      0.013     -0.652      0.515      -0.035       0.018
# population_density                     -0.0001      0.000     -0.677      0.499      -0.000       0.000
# handwashing_facilities                  0.0071      0.009      0.759      0.448      -0.011       0.025
# Europe                                 -0.5781      0.653     -0.886      0.376      -1.859       0.703
# South America                           0.7810      0.603      1.296      0.195      -0.401       1.963
# cardiovasc_death_rate                   0.0016      0.001      1.167      0.243      -0.001       0.004
# people_fully_vaccinated_per_hundred    -0.0168      0.013     -1.246      0.213      -0.043       0.010
# diabetes_prevalence                     0.0550      0.037      1.480      0.139      -0.018       0.128
# Unnamed: 0                              0.0005      0.000      1.625      0.104      -0.000       0.001
# human_development_index                 5.5903      2.675      2.090      0.037       0.342      10.839
# hospital_beds_per_thousand             -0.1620      0.076     -2.131      0.033      -0.311      -0.013
# Africa                                 -1.2549      0.647     -1.940      0.053      -2.524       0.014
# total_boosters_per_hundred             -0.0296      0.011     -2.591      0.010      -0.052      -0.007
# gdp_per_capita                      -2.814e-05   1.07e-05     -2.640      0.008    -4.9e-05   -7.23e-06
# median_age                              0.1347      0.037      3.680      0.000       0.063       0.206
# Asia                                   -1.4142      0.456     -3.102      0.002      -2.309      -0.520
# Oceania                                -2.4726      0.882     -2.802      0.005      -4.204      -0.741
# female_smokers                          0.1223      0.022      5.667      0.000       0.080       0.165
# ==============================================================================
# Omnibus:                     1746.495   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           465057.278
# Skew:                           6.966   Prob(JB):                         0.00
# Kurtosis:                      93.787   Cond. No.                     7.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.22857490407404
# Removed ft:  tests_per_case
# Ft in use: ['extreme_poverty', 'stringency_index', 'positive_rate', 'people_vaccinated_per_hundred', 'population_density', 'handwashing_facilities', 'Europe', 'South America', 'cardiovasc_death_rate', 'people_fully_vaccinated_per_hundred', 'diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.231
# Method:                     Least Squares   F-statistic:                     20.90
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           3.68e-65
# Time:                            22:56:33   Log-Likelihood:                -3720.8
# No. Observations:                    1323   AIC:                             7484.
# Df Residuals:                        1302   BIC:                             7592.
# Df Model:                              20
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -4.8747      1.396     -3.491      0.000      -7.614      -2.135
# stringency_index                        0.0032      0.008      0.403      0.687      -0.012       0.019
# positive_rate                           0.6811      0.951      0.716      0.474      -1.185       2.547
# people_vaccinated_per_hundred          -0.0092      0.013     -0.689      0.491      -0.035       0.017
# population_density                     -0.0001      0.000     -0.653      0.514      -0.000       0.000
# handwashing_facilities                  0.0063      0.009      0.693      0.489      -0.012       0.024
# Europe                                 -0.5691      0.652     -0.873      0.383      -1.848       0.710
# South America                           0.7629      0.600      1.271      0.204      -0.415       1.941
# cardiovasc_death_rate                   0.0016      0.001      1.141      0.254      -0.001       0.004
# people_fully_vaccinated_per_hundred    -0.0165      0.013     -1.227      0.220      -0.043       0.010
# diabetes_prevalence                     0.0523      0.036      1.436      0.151      -0.019       0.124
# Unnamed: 0                              0.0005      0.000      1.655      0.098   -9.22e-05       0.001
# human_development_index                 5.3336      2.581      2.066      0.039       0.270      10.397
# hospital_beds_per_thousand             -0.1612      0.076     -2.123      0.034      -0.310      -0.012
# Africa                                 -1.2256      0.642     -1.910      0.056      -2.485       0.033
# total_boosters_per_hundred             -0.0295      0.011     -2.587      0.010      -0.052      -0.007
# gdp_per_capita                      -2.765e-05   1.06e-05     -2.616      0.009   -4.84e-05   -6.91e-06
# median_age                              0.1340      0.037      3.668      0.000       0.062       0.206
# Asia                                   -1.4308      0.454     -3.155      0.002      -2.320      -0.541
# Oceania                                -2.4958      0.880     -2.837      0.005      -4.222      -0.770
# female_smokers                          0.1227      0.022      5.698      0.000       0.080       0.165
# ==============================================================================
# Omnibus:                     1746.053   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           464660.638
# Skew:                           6.962   Prob(JB):                         0.00
# Kurtosis:                      93.749   Cond. No.                     6.70e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.7e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.230248734484757
# Removed ft:  extreme_poverty
# Ft in use: ['stringency_index', 'positive_rate', 'people_vaccinated_per_hundred', 'population_density', 'handwashing_facilities', 'Europe', 'South America', 'cardiovasc_death_rate', 'people_fully_vaccinated_per_hundred', 'diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.232
# Method:                     Least Squares   F-statistic:                     22.01
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           8.34e-66
# Time:                            22:56:33   Log-Likelihood:                -3720.9
# No. Observations:                    1323   AIC:                             7482.
# Df Residuals:                        1303   BIC:                             7585.
# Df Model:                              19
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -4.8353      1.393     -3.472      0.001      -7.567      -2.103
# positive_rate                           0.6426      0.946      0.679      0.497      -1.213       2.498
# people_vaccinated_per_hundred          -0.0082      0.013     -0.624      0.533      -0.034       0.018
# population_density                     -0.0001      0.000     -0.647      0.518      -0.000       0.000
# handwashing_facilities                  0.0066      0.009      0.730      0.465      -0.011       0.024
# Europe                                 -0.5620      0.652     -0.862      0.389      -1.840       0.716
# South America                           0.7824      0.598      1.308      0.191      -0.391       1.956
# cardiovasc_death_rate                   0.0016      0.001      1.140      0.254      -0.001       0.004
# people_fully_vaccinated_per_hundred    -0.0173      0.013     -1.296      0.195      -0.043       0.009
# diabetes_prevalence                     0.0527      0.036      1.449      0.148      -0.019       0.124
# Unnamed: 0                              0.0005      0.000      1.620      0.106      -0.000       0.001
# human_development_index                 5.4099      2.573      2.102      0.036       0.362      10.458
# hospital_beds_per_thousand             -0.1638      0.076     -2.166      0.030      -0.312      -0.015
# Africa                                 -1.2047      0.639     -1.884      0.060      -2.459       0.050
# total_boosters_per_hundred             -0.0306      0.011     -2.758      0.006      -0.052      -0.009
# gdp_per_capita                      -2.764e-05   1.06e-05     -2.616      0.009   -4.84e-05   -6.91e-06
# median_age                              0.1351      0.036      3.709      0.000       0.064       0.207
# Asia                                   -1.3876      0.441     -3.150      0.002      -2.252      -0.523
# Oceania                                -2.3937      0.842     -2.842      0.005      -4.046      -0.741
# female_smokers                          0.1231      0.022      5.725      0.000       0.081       0.165
# ==============================================================================
# Omnibus:                     1744.961   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           463614.056
# Skew:                           6.954   Prob(JB):                         0.00
# Kurtosis:                      93.646   Cond. No.                     6.69e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.69e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.232275050888603
# Removed ft:  stringency_index
# Ft in use: ['positive_rate', 'people_vaccinated_per_hundred', 'population_density', 'handwashing_facilities', 'Europe', 'South America', 'cardiovasc_death_rate', 'people_fully_vaccinated_per_hundred', 'diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.243
# Model:                                OLS   Adj. R-squared:                  0.232
# Method:                     Least Squares   F-statistic:                     23.21
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           2.12e-66
# Time:                            22:56:33   Log-Likelihood:                -3721.1
# No. Observations:                    1323   AIC:                             7480.
# Df Residuals:                        1304   BIC:                             7579.
# Df Model:                              18
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -4.8116      1.392     -3.457      0.001      -7.542      -2.081
# people_vaccinated_per_hundred          -0.0085      0.013     -0.649      0.517      -0.034       0.017
# population_density                     -0.0001      0.000     -0.680      0.497      -0.000       0.000
# handwashing_facilities                  0.0070      0.009      0.779      0.436      -0.011       0.025
# Europe                                 -0.5126      0.647     -0.792      0.429      -1.783       0.758
# South America                           0.8682      0.585      1.485      0.138      -0.279       2.015
# cardiovasc_death_rate                   0.0017      0.001      1.213      0.225      -0.001       0.004
# people_fully_vaccinated_per_hundred    -0.0171      0.013     -1.289      0.198      -0.043       0.009
# diabetes_prevalence                     0.0500      0.036      1.383      0.167      -0.021       0.121
# Unnamed: 0                              0.0005      0.000      1.593      0.111      -0.000       0.001
# human_development_index                 5.6820      2.541      2.236      0.026       0.696      10.668
# hospital_beds_per_thousand             -0.1653      0.076     -2.187      0.029      -0.314      -0.017
# Africa                                 -1.3060      0.622     -2.101      0.036      -2.526      -0.086
# total_boosters_per_hundred             -0.0314      0.011     -2.845      0.005      -0.053      -0.010
# gdp_per_capita                      -2.789e-05   1.06e-05     -2.642      0.008   -4.86e-05   -7.18e-06
# median_age                              0.1330      0.036      3.666      0.000       0.062       0.204
# Asia                                   -1.3873      0.440     -3.150      0.002      -2.251      -0.523
# ...
# Omnibus:                     1728.814   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           438331.923
# Skew:                           6.849   Prob(JB):                         0.00
# Kurtosis:                      91.113   Cond. No.                     5.71e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.71e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.434294929409575
# Removed ft:  people_fully_vaccinated_per_hundred
# Ft in use: ['diabetes_prevalence', 'Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.231
# Model:                                OLS   Adj. R-squared:                  0.226
# Method:                     Least Squares   F-statistic:                     39.51
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           2.28e-68
# Time:                            22:56:34   Log-Likelihood:                -3730.8
# No. Observations:                    1323   AIC:                             7484.
# Df Residuals:                        1312   BIC:                             7541.
# Df Model:                              10
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -2.0523      1.188     -1.727      0.084      -4.384       0.279
# Unnamed: 0                     0.0005      0.000      1.792      0.073   -5.04e-05       0.001
# human_development_index        4.0969      2.154      1.902      0.057      -0.129       8.323
# hospital_beds_per_thousand    -0.1195      0.070     -1.699      0.090      -0.258       0.018
# Africa                        -2.0259      0.442     -4.582      0.000      -2.893      -1.159
# total_boosters_per_hundred    -0.0489      0.010     -4.920      0.000      -0.068      -0.029
# gdp_per_capita             -3.084e-05   9.71e-06     -3.177      0.002   -4.99e-05   -1.18e-05
# median_age                     0.0936      0.033      2.851      0.004       0.029       0.158
# Asia                          -1.5234      0.349     -4.366      0.000      -2.208      -0.839
# Oceania                       -2.4179      0.596     -4.055      0.000      -3.588      -1.248
# female_smokers                 0.1260      0.018      6.900      0.000       0.090       0.162
# ==============================================================================
# Omnibus:                     1735.535   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           443540.649
# Skew:                           6.898   Prob(JB):                         0.00
# Kurtosis:                      91.633   Cond. No.                     5.71e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.71e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.478123304850975
# Removed ft:  diabetes_prevalence
# Ft in use: ['Unnamed: 0', 'human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.230
# Model:                                OLS   Adj. R-squared:                  0.224
# Method:                     Least Squares   F-statistic:                     43.47
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.61e-68
# Time:                            22:56:34   Log-Likelihood:                -3732.4
# No. Observations:                    1323   AIC:                             7485.
# Df Residuals:                        1313   BIC:                             7537.
# Df Model:                               9
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -1.7016      1.173     -1.450      0.147      -4.003       0.600
# human_development_index        3.9935      2.155      1.853      0.064      -0.234       8.221
# hospital_beds_per_thousand    -0.1218      0.070     -1.730      0.084      -0.260       0.016
# Africa                        -1.9991      0.442     -4.520      0.000      -2.867      -1.132
# total_boosters_per_hundred    -0.0489      0.010     -4.919      0.000      -0.068      -0.029
# gdp_per_capita             -3.033e-05   9.71e-06     -3.123      0.002   -4.94e-05   -1.13e-05
# median_age                     0.0947      0.033      2.882      0.004       0.030       0.159
# Asia                          -1.4515      0.347     -4.184      0.000      -2.132      -0.771
# Oceania                       -2.3017      0.593     -3.880      0.000      -3.466      -1.138
# female_smokers                 0.1271      0.018      6.957      0.000       0.091       0.163
# ==============================================================================
# Omnibus:                     1737.076   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           446983.042
# Skew:                           6.907   Prob(JB):                         0.00
# Kurtosis:                      91.981   Cond. No.                     5.70e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.7e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.518462483610378
# Removed ft:  Unnamed: 0
# Ft in use: ['human_development_index', 'hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.228
# Model:                                OLS   Adj. R-squared:                  0.223
# Method:                     Least Squares   F-statistic:                     48.39
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           1.21e-68
# Time:                            22:56:34   Log-Likelihood:                -3734.1
# No. Observations:                    1323   AIC:                             7486.
# Df Residuals:                        1314   BIC:                             7533.
# Df Model:                               8
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -0.0492      0.763     -0.065      0.949      -1.546       1.448
# hospital_beds_per_thousand    -0.1055      0.070     -1.509      0.132      -0.243       0.032
# Africa                        -2.2420      0.423     -5.303      0.000      -3.071      -1.413
# total_boosters_per_hundred    -0.0472      0.010     -4.762      0.000      -0.067      -0.028
# gdp_per_capita             -2.131e-05   8.41e-06     -2.534      0.011   -3.78e-05   -4.81e-06
# median_age                     0.1309      0.026      4.947      0.000       0.079       0.183
# Asia                          -1.5272      0.345     -4.429      0.000      -2.204      -0.851
# Oceania                       -2.2176      0.592     -3.745      0.000      -3.379      -1.056
# female_smokers                 0.1237      0.018      6.800      0.000       0.088       0.159
# ==============================================================================
# Omnibus:                     1735.068   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           444616.759
# Skew:                           6.893   Prob(JB):                         0.00
# Kurtosis:                      91.744   Cond. No.                     2.17e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.561663521092512
# Removed ft:  human_development_index
# Ft in use: ['hospital_beds_per_thousand', 'Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.226
# Model:                                OLS   Adj. R-squared:                  0.222
# Method:                     Least Squares   F-statistic:                     54.92
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           4.81e-69
# Time:                            22:56:34   Log-Likelihood:                -3735.3
# No. Observations:                    1323   AIC:                             7487.
# Df Residuals:                        1315   BIC:                             7528.
# Df Model:                               7
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.2993      0.728      0.411      0.681      -1.128       1.727
# Africa                        -2.3356      0.418     -5.582      0.000      -3.156      -1.515
# total_boosters_per_hundred    -0.0473      0.010     -4.773      0.000      -0.067      -0.028
# gdp_per_capita             -1.932e-05   8.31e-06     -2.324      0.020   -3.56e-05   -3.01e-06
# median_age                     0.1116      0.023      4.814      0.000       0.066       0.157
# Asia                          -1.6092      0.341     -4.724      0.000      -2.277      -0.941
# Oceania                       -2.2639      0.592     -3.827      0.000      -3.424      -1.103
# female_smokers                 0.1192      0.018      6.640      0.000       0.084       0.154
# ==============================================================================
# Omnibus:                     1735.116   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           442604.576
# Skew:                           6.896   Prob(JB):                         0.00
# Kurtosis:                      91.538   Cond. No.                     2.09e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.590356933467188
# Removed ft:  hospital_beds_per_thousand
# Ft in use: ['Africa', 'total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# ********************
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     new_deaths_per_million   R-squared:                       0.208
# Model:                                OLS   Adj. R-squared:                  0.204
# Method:                     Least Squares   F-statistic:                     57.56
# Date:                    Sat, 04 Jun 2022   Prob (F-statistic):           2.40e-63
# Time:                            22:56:34   Log-Likelihood:                -3750.8
# No. Observations:                    1323   AIC:                             7516.
# Df Residuals:                        1316   BIC:                             7552.
# Df Model:                               6
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -2.7167      0.493     -5.510      0.000      -3.684      -1.749
# total_boosters_per_hundred    -0.0334      0.010     -3.445      0.001      -0.052      -0.014
# gdp_per_capita             -2.532e-05   8.34e-06     -3.038      0.002   -4.17e-05   -8.97e-06
# median_age                     0.1717      0.021      8.269      0.000       0.131       0.212
# Asia                          -0.6698      0.300     -2.236      0.026      -1.258      -0.082
# Oceania                       -1.3520      0.575     -2.351      0.019      -2.480      -0.224
# female_smokers                 0.1283      0.018      7.091      0.000       0.093       0.164
# ==============================================================================
# Omnibus:                     1752.327   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           459649.949
# Skew:                           7.019   Prob(JB):                         0.00
# Kurtosis:                      93.229   Cond. No.                     1.46e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 16.983516501432003
# Removed ft:  Africa
# Ft in use: ['total_boosters_per_hundred', 'gdp_per_capita', 'median_age', 'Asia', 'Oceania', 'female_smokers']
# Break due to stopping rule: max pvalue = 0.025519317089049687 < 0.05

# %%
backward_reg('New cases per million model:', cases_ft, new_cases_per_million)
# Out:
# New cases per million model:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.340
# Model:                               OLS   Adj. R-squared:                  0.326
# Method:                    Least Squares   F-statistic:                     25.64
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           5.23e-98
# Time:                           22:56:34   Log-Likelihood:                -11567.
# No. Observations:                   1323   AIC:                         2.319e+04
# Df Residuals:                       1296   BIC:                         2.333e+04
# Df Model:                             26
# Covariance Type:               nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                -225.3418    887.163     -0.254      0.800   -1965.774    1515.090
# stringency_index                       -0.2472      2.968     -0.083      0.934      -6.070       5.576
# people_fully_vaccinated_per_hundred    -0.9990      5.115     -0.195      0.845     -11.034       9.036
# people_vaccinated_per_hundred           1.4786      5.110      0.289      0.772      -8.546      11.503
# extreme_poverty                         1.9105      4.565      0.419      0.676      -7.045      10.866
# handwashing_facilities                 -1.7993      3.559     -0.506      0.613      -8.781       5.183
# cardiovasc_death_rate                  -0.3385      0.568     -0.596      0.551      -1.453       0.776
# female_smokers                          5.9068      8.819      0.670      0.503     -11.394      23.208
# aged_65_older                         -39.2187     53.589     -0.732      0.464    -144.350      65.912
# North America                        -153.5935    201.416     -0.763      0.446    -548.732     241.544
# male_smokers                           -3.7665      4.828     -0.780      0.435     -13.238       5.705
# Asia                                  213.7286    202.472      1.056      0.291    -183.479     610.936
# Unnamed: 0                             -0.1223      0.114     -1.069      0.285      -0.347       0.102
# Europe                                287.7499    267.735      1.075      0.283    -237.492     812.992
# life_expectancy                       -22.6606     16.399     -1.382      0.167     -54.831       9.510
# tests_per_case                         -0.0060      0.004     -1.416      0.157      -0.014       0.002
# population_density                     -0.1069      0.063     -1.702      0.089      -0.230       0.016
# Oceania                              -609.0639    302.152     -2.016      0.044   -1201.824     -16.304
# South America                        -531.0942    213.900     -2.483      0.013    -950.722    -111.467
# median_age                            -49.2162     20.044     -2.455      0.014     -88.538      -9.894
# Africa                                566.9312    218.307      2.597      0.010     138.657     995.206
# aged_70_older                         221.3662     80.852      2.738      0.006      62.750     379.982
# hospital_beds_per_thousand            -81.3723     29.818     -2.729      0.006    -139.870     -22.875
# diabetes_prevalence                    43.4663     15.267      2.847      0.004      13.515      73.417
# human_development_index              3242.1884    980.584      3.306      0.001    1318.483    5165.893
# total_boosters_per_hundred             17.7178      4.246      4.172      0.000       9.387      26.049
# new_tests_smoothed_per_thousand        28.2450      4.462      6.330      0.000      19.491      36.999
# positive_rate                        2705.5638    392.389      6.895      0.000    1935.777    3475.350
# ==============================================================================
# Omnibus:                     2056.463   Durbin-Watson:                   1.419
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1539113.050
# Skew:                           9.173   Prob(JB):                         0.00
# Kurtosis:                     169.084   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.49e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2299560.511172696
# Removed ft:  gdp_per_capita
# Ft in use: ['stringency_index', 'people_fully_vaccinated_per_hundred', 'people_vaccinated_per_hundred', 'extreme_poverty', 'handwashing_facilities', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'North America', 'male_smokers', 'Asia', 'Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.340
# Model:                               OLS   Adj. R-squared:                  0.327
# Method:                    Least Squares   F-statistic:                     26.68
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.00e-98
# Time:                           22:56:34   Log-Likelihood:                -11567.
# No. Observations:                   1323   AIC:                         2.319e+04
# Df Residuals:                       1297   BIC:                         2.332e+04
# Df Model:                             25
# Covariance Type:               nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                -232.2891    882.895     -0.263      0.793   -1964.348    1499.770
# people_fully_vaccinated_per_hundred    -0.9384      5.061     -0.185      0.853     -10.867       8.991
# people_vaccinated_per_hundred           1.3995      5.019      0.279      0.780      -8.447      11.246
# extreme_poverty                         1.8994      4.561      0.416      0.677      -7.049      10.847
# handwashing_facilities                 -1.8264      3.543     -0.516      0.606      -8.776       5.124
# cardiovasc_death_rate                  -0.3368      0.567     -0.594      0.553      -1.450       0.776
# female_smokers                          5.8871      8.812      0.668      0.504     -11.401      23.175
# aged_65_older                         -39.3788     53.534     -0.736      0.462    -144.402      65.644
# North America                        -152.4338    200.858     -0.759      0.448    -546.475     241.608
# male_smokers                           -3.7905      4.818     -0.787      0.432     -13.242       5.661
# Asia                                  211.9006    201.202      1.053      0.292    -182.816     606.617
# Unnamed: 0                             -0.1213      0.114     -1.067      0.286      -0.344       0.102
# Europe                                288.5437    267.463      1.079      0.281    -236.164     813.252
# life_expectancy                       -22.5885     16.369     -1.380      0.168     -54.702       9.525
# tests_per_case                         -0.0060      0.004     -1.420      0.156      -0.014       0.002
# population_density                     -0.1069      0.063     -1.703      0.089      -0.230       0.016
# Oceania                              -615.8972    290.691     -2.119      0.034   -1186.173     -45.622
# South America                        -531.3471    213.796     -2.485      0.013    -950.771    -111.923
# median_age                            -49.3236     19.995     -2.467      0.014     -88.549     -10.098
# Africa                                566.9446    218.224      2.598      0.009     138.834     995.055
# aged_70_older                         221.6274     80.761      2.744      0.006      63.192     380.063
# hospital_beds_per_thousand            -81.1287     29.663     -2.735      0.006    -139.322     -22.936
# diabetes_prevalence                    43.4389     15.258      2.847      0.004      13.507      73.371
# human_development_index              3233.6834    974.880      3.317      0.001    1321.170    5146.197
# total_boosters_per_hundred             17.7997      4.130      4.310      0.000       9.698      25.901
# new_tests_smoothed_per_thousand        28.2437      4.461      6.332      0.000      19.493      36.995
# positive_rate                        2708.3945    390.765      6.931      0.000    1941.795    3474.994
# ==============================================================================
# Omnibus:                     2056.499   Durbin-Watson:                   1.419
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1539417.029
# Skew:                           9.173   Prob(JB):                         0.00
# Kurtosis:                     169.100   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.5e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2299572.82211377
# Removed ft:  stringency_index
# Ft in use: ['people_fully_vaccinated_per_hundred', 'people_vaccinated_per_hundred', 'extreme_poverty', 'handwashing_facilities', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'North America', 'male_smokers', 'Asia', 'Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.340
# Model:                               OLS   Adj. R-squared:                  0.327
# Method:                    Least Squares   F-statistic:                     27.81
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):           1.91e-99
# Time:                           22:56:34   Log-Likelihood:                -11567.
# No. Observations:                   1323   AIC:                         2.318e+04
# Df Residuals:                       1298   BIC:                         2.331e+04
# Df Model:                             24
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -211.9462    875.725     -0.242      0.809   -1929.938    1506.045
# people_vaccinated_per_hundred       0.6936      3.269      0.212      0.832      -5.720       7.107
# extreme_poverty                     1.8449      4.550      0.405      0.685      -7.081      10.771
# handwashing_facilities             -1.8729      3.532     -0.530      0.596      -8.803       5.057
# cardiovasc_death_rate              -0.3175      0.558     -0.569      0.569      -1.411       0.776
# female_smokers                      5.8551      8.807      0.665      0.506     -11.423      23.133
# aged_65_older                     -39.3576     53.514     -0.735      0.462    -144.341      65.626
# North America                    -148.9528    199.904     -0.745      0.456    -541.123     243.217
# male_smokers                       -3.8234      4.813     -0.794      0.427     -13.265       5.618
# Asia                              213.3182    200.981      1.061      0.289    -180.966     607.602
# Unnamed: 0                         -0.1221      0.114     -1.076      0.282      -0.345       0.101
# Europe                            296.9997    263.448      1.127      0.260    -219.831     813.830
# life_expectancy                   -22.7997     16.324     -1.397      0.163     -54.823       9.224
# tests_per_case                     -0.0060      0.004     -1.432      0.152      -0.014       0.002
# population_density                 -0.1060      0.063     -1.695      0.090      -0.229       0.017
# Oceania                          -612.3579    289.955     -2.112      0.035   -1181.190     -43.525
# South America                    -526.7451    212.272     -2.481      0.013    -943.178    -110.312
# median_age                        -49.4898     19.967     -2.479      0.013     -88.661     -10.318
# Africa                            565.7917    218.054      2.595      0.010     138.015     993.568
# aged_70_older                     221.5978     80.730      2.745      0.006      63.222     379.974
# hospital_beds_per_thousand        -81.0531     29.649     -2.734      0.006    -139.219     -22.887
# diabetes_prevalence                43.2598     15.221      2.842      0.005      13.399      73.121
# human_development_index          3226.9146    973.833      3.314      0.001    1316.455    5137.375
# total_boosters_per_hundred         17.6905      4.086      4.330      0.000       9.675      25.706
# new_tests_smoothed_per_thousand    28.1759      4.444      6.340      0.000      19.458      36.894
# positive_rate                    2706.7445    390.518      6.931      0.000    1940.629    3472.860
# ==============================================================================
# Omnibus:                     2055.834   Durbin-Watson:                   1.420
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1536466.097
# Skew:                           9.168   Prob(JB):                         0.00
# Kurtosis:                     168.940   Cond. No.                     2.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.5e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2299633.770301968
# Removed ft:  people_fully_vaccinated_per_hundred
# Ft in use: ['people_vaccinated_per_hundred', 'extreme_poverty', 'handwashing_facilities', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'North America', 'male_smokers', 'Asia', 'Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.340
# Model:                               OLS   Adj. R-squared:                  0.328
# Method:                    Least Squares   F-statistic:                     29.04
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          3.58e-100
# Time:                           22:56:34   Log-Likelihood:                -11567.
# No. Observations:                   1323   AIC:                         2.318e+04
# Df Residuals:                       1299   BIC:                         2.331e+04
# Df Model:                             23
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -248.8730    857.939     -0.290      0.772   -1931.971    1434.225
# extreme_poverty                     1.7821      4.539      0.393      0.695      -7.122      10.686
# handwashing_facilities             -2.0053      3.476     -0.577      0.564      -8.824       4.813
# cardiovasc_death_rate              -0.3439      0.543     -0.633      0.527      -1.410       0.722
# female_smokers                      5.6809      8.766      0.648      0.517     -11.516      22.878
# aged_65_older                     -39.1908     53.489     -0.733      0.464    -144.124      65.743
# North America                    -155.1031    197.718     -0.784      0.433    -542.985     232.779
# male_smokers                       -3.6403      4.733     -0.769      0.442     -12.925       5.645
# Asia                              206.6975    198.471      1.041      0.298    -182.661     596.056
# Unnamed: 0                         -0.1224      0.113     -1.079      0.281      -0.345       0.100
# Europe                            290.0812    261.326      1.110      0.267    -222.586     802.748
# life_expectancy                   -22.1774     16.052     -1.382      0.167     -53.669       9.314
# tests_per_case                     -0.0060      0.004     -1.423      0.155      -0.014       0.002
# population_density                 -0.1070      0.062     -1.715      0.087      -0.229       0.015
# Oceania                          -617.5938    288.797     -2.139      0.033   -1184.153     -51.034
# South America                    -524.2978    211.880     -2.475      0.013    -939.962    -108.633
# median_age                        -48.5837     19.498     -2.492      0.013     -86.835     -10.333
# Africa                            551.3430    207.070      2.663      0.008     145.114     957.571
# aged_70_older                     220.1439     80.409      2.738      0.006      62.397     377.890
# hospital_beds_per_thousand        -81.4915     29.566     -2.756      0.006    -139.494     -23.489
# diabetes_prevalence                42.9015     15.122      2.837      0.005      13.236      72.567
# human_development_index          3267.2508    954.744      3.422      0.001    1394.243    5140.259
# total_boosters_per_hundred         17.8924      3.972      4.504      0.000      10.100      25.685
# new_tests_smoothed_per_thousand    28.0668      4.412      6.361      0.000      19.411      36.723
# positive_rate                    2699.5980    388.919      6.941      0.000    1936.619    3462.577
# ==============================================================================
# Omnibus:                     2056.996   Durbin-Watson:                   1.419
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1542111.210
# Skew:                           9.177   Prob(JB):                         0.00
# Kurtosis:                     169.247   Cond. No.                     1.64e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.5e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2299713.517629885
# Removed ft:  people_vaccinated_per_hundred
# Ft in use: ['extreme_poverty', 'handwashing_facilities', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'North America', 'male_smokers', 'Asia', 'Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.340
# Model:                               OLS   Adj. R-squared:                  0.328
# Method:                    Least Squares   F-statistic:                     30.37
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          6.91e-101
# Time:                           22:56:34   Log-Likelihood:                -11567.
# No. Observations:                   1323   AIC:                         2.318e+04
# Df Residuals:                       1300   BIC:                         2.330e+04
# Df Model:                             22
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -135.1957    807.353     -0.167      0.867   -1719.053    1448.661
# handwashing_facilities             -2.3125      3.385     -0.683      0.495      -8.954       4.329
# cardiovasc_death_rate              -0.3622      0.541     -0.669      0.503      -1.424       0.699
# female_smokers                      5.8916      8.746      0.674      0.501     -11.267      23.050
# aged_65_older                     -39.1951     53.471     -0.733      0.464    -144.095      65.704
# North America                    -135.5882    191.308     -0.709      0.479    -510.893     239.717
# male_smokers                       -3.7625      4.721     -0.797      0.426     -13.024       5.499
# Asia                              222.5137    194.277      1.145      0.252    -158.618     603.645
# Unnamed: 0                         -0.1190      0.113     -1.052      0.293      -0.341       0.103
# Europe                            313.5090    254.341      1.233      0.218    -185.454     812.472
# life_expectancy                   -22.4082     16.036     -1.397      0.163     -53.868       9.052
# tests_per_case                     -0.0060      0.004     -1.420      0.156      -0.014       0.002
# population_density                 -0.1049      0.062     -1.688      0.092      -0.227       0.017
# Oceania                          -607.3364    287.519     -2.112      0.035   -1171.389     -43.283
# South America                    -514.5555    210.354     -2.446      0.015    -927.225    -101.886
# median_age                        -48.9740     19.466     -2.516      0.012     -87.163     -10.785
# Africa                            586.2617    186.940      3.136      0.002     219.524     953.000
# aged_70_older                     220.4496     80.379      2.743      0.006      62.762     378.137
# hospital_beds_per_thousand        -81.2448     29.550     -2.749      0.006    -139.216     -23.274
# diabetes_prevalence                42.0526     14.962      2.811      0.005      12.701      71.404
# human_development_index          3182.8035    929.902      3.423      0.001    1358.530    5007.077
# total_boosters_per_hundred         17.9332      3.969      4.518      0.000      10.146      25.721
# new_tests_smoothed_per_thousand    28.1717      4.403      6.398      0.000      19.534      36.809
# positive_rate                    2705.7232    388.480      6.965      0.000    1943.607    3467.840
# ==============================================================================
# Omnibus:                     2057.202   Durbin-Watson:                   1.418
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1543068.127
# Skew:                           9.179   Prob(JB):                         0.00
# Kurtosis:                     169.298   Cond. No.                     4.76e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.54e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2299986.4673581724
# Removed ft:  extreme_poverty
# Ft in use: ['handwashing_facilities', 'cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'North America', 'male_smokers', 'Asia', 'Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.339
# Model:                               OLS   Adj. R-squared:                  0.329
# Method:                    Least Squares   F-statistic:                     31.81
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          1.52e-101
# Time:                           22:56:34   Log-Likelihood:                -11567.
# No. Observations:                   1323   AIC:                         2.318e+04
# Df Residuals:                       1301   BIC:                         2.329e+04
# Df Model:                             21
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                             -55.3557    798.684     -0.069      0.945   -1622.205    1511.494
# cardiovasc_death_rate              -0.3982      0.538     -0.740      0.460      -1.455       0.658
# female_smokers                      6.2207      8.731      0.712      0.476     -10.909      23.350
# aged_65_older                     -38.1902     53.440     -0.715      0.475    -143.028      66.648
# North America                    -161.5026    187.470     -0.861      0.389    -529.279     206.274
# male_smokers                       -4.0978      4.695     -0.873      0.383     -13.307       5.112
# Asia                              221.8494    194.235      1.142      0.254    -159.199     602.898
# Unnamed: 0                         -0.1251      0.113     -1.110      0.267      -0.346       0.096
# Europe                            262.3965    243.035      1.080      0.280    -214.388     739.181
# life_expectancy                   -24.0417     15.854     -1.516      0.130     -55.143       7.060
# tests_per_case                     -0.0059      0.004     -1.416      0.157      -0.014       0.002
# population_density                 -0.0998      0.062     -1.618      0.106      -0.221       0.021
# Oceania                          -519.7682    257.307     -2.020      0.044   -1024.550     -14.986
# South America                    -513.0591    210.299     -2.440      0.015    -925.622    -100.496
# median_age                        -49.2215     19.459     -2.530      0.012     -87.396     -11.047
# Africa                            654.7283    157.767      4.150      0.000     345.222     964.234
# aged_70_older                     220.3603     80.363      2.742      0.006      62.705     378.015
# hospital_beds_per_thousand        -80.3081     29.512     -2.721      0.007    -138.205     -22.412
# diabetes_prevalence                41.6780     14.948      2.788      0.005      12.352      71.004
# human_development_index          3051.3141    909.575      3.355      0.001    1266.920    4835.708
# total_boosters_per_hundred         18.0486      3.965      4.552      0.000      10.270      25.827
# new_tests_smoothed_per_thousand    28.1853      4.402      6.403      0.000      19.550      36.821
# positive_rate                    2690.9414    387.797      6.939      0.000    1930.165    3451.718
# ==============================================================================
# Omnibus:                     2057.675   Durbin-Watson:                   1.418
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1543424.098
# Skew:                           9.183   Prob(JB):                         0.00
# Kurtosis:                     169.317   Cond. No.                     2.95e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.71e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2300812.0249436065
# Removed ft:  handwashing_facilities
# Ft in use: ['cardiovasc_death_rate', 'female_smokers', 'aged_65_older', 'North America', 'male_smokers', 'Asia', 'Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.339
# Model:                               OLS   Adj. R-squared:                  0.329
# Method:                    Least Squares   F-statistic:                     33.39
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          3.37e-102
# Time:                           22:56:34   Log-Likelihood:                -11568.
# No. Observations:                   1323   AIC:                         2.318e+04
# Df Residuals:                       1302   BIC:                         2.329e+04
# Df Model:                             20
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -344.2488    696.531     -0.494      0.621   -1710.695    1022.198
# female_smokers                      6.8329      8.691      0.786      0.432     -10.216      23.882
# aged_65_older                     -40.4882     53.340     -0.759      0.448    -145.131      64.154
# North America                    -196.9900    181.194     -1.087      0.277    -552.454     158.474
# male_smokers                       -5.0980      4.495     -1.134      0.257     -13.916       3.720
# Asia                              173.9513    183.089      0.950      0.342    -185.230     533.133
# Unnamed: 0                         -0.1277      0.113     -1.133      0.257      -0.349       0.093
# Europe                            188.9963    221.811      0.852      0.394    -246.149     624.142
# life_expectancy                   -21.0883     15.340     -1.375      0.169     -51.182       9.005
# tests_per_case                     -0.0058      0.004     -1.379      0.168      -0.014       0.002
# population_density                 -0.0994      0.062     -1.612      0.107      -0.220       0.022
# Oceania                          -602.2801    231.823     -2.598      0.009   -1057.069    -147.492
# South America                    -544.4593    205.933     -2.644      0.008    -948.457    -140.462
# median_age                        -50.2947     19.401     -2.592      0.010     -88.356     -12.233
# Africa                            636.5330    155.810      4.085      0.000     330.866     942.200
# aged_70_older                     226.2063     79.959      2.829      0.005      69.343     383.069
# hospital_beds_per_thousand        -84.7967     28.876     -2.937      0.003    -141.446     -28.148
# diabetes_prevalence                40.2635     14.823      2.716      0.007      11.184      69.343
# human_development_index          3166.2589    896.043      3.534      0.000    1408.412    4924.105
# total_boosters_per_hundred         18.5249      3.912      4.736      0.000      10.851      26.199
# new_tests_smoothed_per_thousand    28.2657      4.400      6.424      0.000      19.634      36.897
# positive_rate                    2652.8377    384.293      6.903      0.000    1898.936    3406.739
# ==============================================================================
# Omnibus:                     2056.223   Durbin-Watson:                   1.417
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1535519.894
# Skew:                           9.172   Prob(JB):                         0.00
# Kurtosis:                     168.888   Cond. No.                     2.51e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.35e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2301779.422048805
# Removed ft:  cardiovasc_death_rate
# Ft in use: ['female_smokers', 'aged_65_older', 'North America', 'male_smokers', 'Asia', 'Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.339
# Model:                               OLS   Adj. R-squared:                  0.329
# Method:                    Least Squares   F-statistic:                     35.12
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          7.57e-103
# Time:                           22:56:34   Log-Likelihood:                -11568.
# No. Observations:                   1323   AIC:                         2.318e+04
# Df Residuals:                       1303   BIC:                         2.328e+04
# Df Model:                             19
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -295.7536    693.693     -0.426      0.670   -1656.631    1065.124
# aged_65_older                     -37.4115     53.189     -0.703      0.482    -141.757      66.934
# North America                    -206.2907    180.781     -1.141      0.254    -560.945     148.363
# male_smokers                       -4.0865      4.306     -0.949      0.343     -12.534       4.361
# Asia                              145.9520    179.566      0.813      0.416    -206.318     498.222
# Unnamed: 0                         -0.1287      0.113     -1.142      0.254      -0.350       0.092
# Europe                            252.2702    206.667      1.221      0.222    -153.165     657.706
# life_expectancy                   -21.6502     15.321     -1.413      0.158     -51.707       8.406
# tests_per_case                     -0.0060      0.004     -1.437      0.151      -0.014       0.002
# population_density                 -0.1019      0.062     -1.655      0.098      -0.223       0.019
# Oceania                          -575.8235    229.335     -2.511      0.012   -1025.729    -125.918
# South America                    -526.6413    204.653     -2.573      0.010    -928.126    -125.157
# median_age                        -52.3341     19.224     -2.722      0.007     -90.048     -14.620
# Africa                            614.7797    153.312      4.010      0.000     314.015     915.544
# aged_70_older                     230.1854     79.787      2.885      0.004      73.660     386.711
# hospital_beds_per_thousand        -85.9940     28.832     -2.983      0.003    -142.556     -29.432
# diabetes_prevalence                41.8653     14.680      2.852      0.004      13.066      70.665
# human_development_index          3192.4260    895.294      3.566      0.000    1436.051    4948.801
# total_boosters_per_hundred         19.0559      3.852      4.946      0.000      11.498      26.614
# new_tests_smoothed_per_thousand    28.1070      4.395      6.396      0.000      19.486      36.728
# positive_rate                    2641.6751    383.974      6.880      0.000    1888.399    3394.951
# ==============================================================================
# Omnibus:                     2055.044   Durbin-Watson:                   1.416
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1533191.785
# Skew:                           9.161   Prob(JB):                         0.00
# Kurtosis:                     168.763   Cond. No.                     1.47e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.84e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2302872.2821137696
# Removed ft:  female_smokers
# Ft in use: ['aged_65_older', 'North America', 'male_smokers', 'Asia', 'Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.338
# Model:                               OLS   Adj. R-squared:                  0.329
# Method:                    Least Squares   F-statistic:                     37.06
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          1.56e-103
# Time:                           22:56:34   Log-Likelihood:                -11568.
# No. Observations:                   1323   AIC:                         2.317e+04
# Df Residuals:                       1304   BIC:                         2.327e+04
# Df Model:                             18
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -323.7071    692.420     -0.468      0.640   -1682.085    1034.671
# North America                    -211.9316    180.568     -1.174      0.241    -566.167     142.304
# male_smokers                       -3.9733      4.302     -0.924      0.356     -12.413       4.467
# Asia                              152.7765    179.269      0.852      0.394    -198.910     504.463
# Unnamed: 0                         -0.1265      0.113     -1.124      0.261      -0.347       0.094
# Europe                            231.1851    204.441      1.131      0.258    -169.885     632.255
# life_expectancy                   -20.9025     15.281     -1.368      0.172     -50.881       9.076
# tests_per_case                     -0.0064      0.004     -1.558      0.119      -0.015       0.002
# population_density                 -0.1124      0.060     -1.881      0.060      -0.230       0.005
# Oceania                          -580.6198    229.189     -2.533      0.011   -1030.239    -131.000
# South America                    -533.3863    204.388     -2.610      0.009    -934.352    -132.421
# median_age                        -52.8021     19.209     -2.749      0.006     -90.486     -15.118
# Africa                            618.2691    153.202      4.036      0.000     317.720     918.818
# aged_70_older                     179.6220     34.609      5.190      0.000     111.727     247.517
# hospital_beds_per_thousand        -86.2692     28.824     -2.993      0.003    -142.815     -29.723
# diabetes_prevalence                41.2964     14.655      2.818      0.005      12.546      70.047
# human_development_index          3120.3961    889.245      3.509      0.000    1375.888    4864.904
# total_boosters_per_hundred         19.0944      3.851      4.958      0.000      11.539      26.650
# new_tests_smoothed_per_thousand    28.3926      4.375      6.490      0.000      19.810      36.975
# positive_rate                    2641.8783    383.900      6.882      0.000    1888.749    3395.007
# ==============================================================================
# Omnibus:                     2053.963   Durbin-Watson:                   1.417
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1530534.800
# Skew:                           9.151   Prob(JB):                         0.00
# Kurtosis:                     168.620   Cond. No.                     4.33e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.89e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MSE: 2303746.64818874
# Removed ft:  aged_65_older
# Ft in use: ['North America', 'male_smokers', 'Asia', 'Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.338
# Model:                               OLS   Adj. R-squared:                  0.329
# Method:                    Least Squares   F-statistic:                     37.06
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          1.56e-103
# Time:                           22:56:34   Log-Likelihood:                -11568.
# No. Observations:                   1323   AIC:                         2.317e+04
# Df Residuals:                       1304   BIC:                         2.327e+04
# Df Model:                             18
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -535.6387    832.195     -0.644      0.520   -2168.227    1096.949
# male_smokers                       -3.9733      4.302     -0.924      0.356     -12.413       4.467
# Asia                              364.7081    181.679      2.007      0.045       8.293     721.123
# Unnamed: 0                         -0.1265      0.113     -1.124      0.261      -0.347       0.094
# Europe                            443.1167    223.210      1.985      0.047       5.227     881.006
# life_expectancy                   -20.9025     15.281     -1.368      0.172     -50.881       9.076
# tests_per_case                     -0.0064      0.004     -1.558      0.119      -0.015       0.002
# population_density                 -0.1124      0.060     -1.881      0.060      -0.230       0.005
# Oceania                          -368.6882    263.127     -1.401      0.161    -884.886     147.510
# South America                    -321.4547    217.378     -1.479      0.139    -747.903     104.994
# median_age                        -52.8021     19.209     -2.749      0.006     -90.486     -15.118
# Africa                            830.2007    200.307      4.145      0.000     437.242    1223.159
# aged_70_older                     179.6220     34.609      5.190      0.000     111.727     247.517
# hospital_beds_per_thousand        -86.2692     28.824     -2.993      0.003    -142.815     -29.723
# diabetes_prevalence                41.2964     14.655      2.818      0.005      12.546      70.047
# human_development_index          3120.3961    889.245      3.509      0.000    1375.888    4864.904
# total_boosters_per_hundred         19.0944      3.851      4.958      0.000      11.539      26.650
# new_tests_smoothed_per_thousand    28.3926      4.375      6.490      0.000      19.810      36.975
# positive_rate                    2641.8783    383.900      6.882      0.000    1888.749    3395.007
# ==============================================================================
# Omnibus:                     2053.963   Durbin-Watson:                   1.417
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1530534.800
# Skew:                           9.151   Prob(JB):                         0.00
# Kurtosis:                     168.620   Cond. No.                     2.42e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.42e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 2303746.6481887316
# Removed ft:  North America
# ...
# Omnibus:                     2041.592   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1473936.468
# Skew:                           9.049   Prob(JB):                         0.00
# Kurtosis:                     165.513   Cond. No.                     2.42e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.42e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 2310875.321706077
# Removed ft:  Asia
# Ft in use: ['Unnamed: 0', 'Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.336
# Model:                               OLS   Adj. R-squared:                  0.328
# Method:                    Least Squares   F-statistic:                     44.09
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          5.79e-105
# Time:                           22:56:34   Log-Likelihood:                -11571.
# No. Observations:                   1323   AIC:                         2.317e+04
# Df Residuals:                       1307   BIC:                         2.326e+04
# Df Model:                             15
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -525.5215    805.419     -0.652      0.514   -2105.576    1054.533
# Europe                            225.2335    196.343      1.147      0.252    -159.949     610.416
# life_expectancy                   -20.6576     15.236     -1.356      0.175     -50.547       9.232
# tests_per_case                     -0.0058      0.004     -1.406      0.160      -0.014       0.002
# population_density                 -0.0955      0.059     -1.616      0.106      -0.212       0.020
# Oceania                          -608.3601    236.428     -2.573      0.010   -1072.179    -144.541
# South America                    -509.3714    192.608     -2.645      0.008    -887.225    -131.518
# median_age                        -49.9994     18.826     -2.656      0.008     -86.932     -13.067
# Africa                            627.7329    170.790      3.675      0.000     292.680     962.785
# aged_70_older                     162.3474     32.782      4.952      0.000      98.036     226.658
# hospital_beds_per_thousand        -81.6970     27.409     -2.981      0.003    -135.467     -27.927
# diabetes_prevalence                33.5837     14.149      2.374      0.018       5.827      61.341
# human_development_index          3121.3288    879.238      3.550      0.000    1396.457    4846.201
# total_boosters_per_hundred         20.7652      3.744      5.546      0.000      13.420      28.111
# new_tests_smoothed_per_thousand    28.7192      4.306      6.669      0.000      20.272      37.167
# positive_rate                    2661.1091    378.300      7.034      0.000    1918.967    3403.251
# ==============================================================================
# Omnibus:                     2043.254   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1482804.946
# Skew:                           9.062   Prob(JB):                         0.00
# Kurtosis:                     166.005   Cond. No.                     2.42e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.42e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 2312243.526748708
# Removed ft:  Unnamed: 0
# Ft in use: ['Europe', 'life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.335
# Model:                               OLS   Adj. R-squared:                  0.328
# Method:                    Least Squares   F-statistic:                     47.13
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          1.58e-105
# Time:                           22:56:34   Log-Likelihood:                -11571.
# No. Observations:                   1323   AIC:                         2.317e+04
# Df Residuals:                       1308   BIC:                         2.325e+04
# Df Model:                             14
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            -375.4375    794.817     -0.472      0.637   -1934.693    1183.818
# life_expectancy                   -24.2766     14.907     -1.628      0.104     -53.522       4.968
# tests_per_case                     -0.0063      0.004     -1.550      0.121      -0.014       0.002
# population_density                 -0.1117      0.057     -1.945      0.052      -0.224       0.001
# Oceania                          -634.8832    235.323     -2.698      0.007   -1096.534    -173.232
# South America                    -566.5716    186.064     -3.045      0.002    -931.587    -201.556
# median_age                        -47.8580     18.735     -2.554      0.011     -84.613     -11.103
# Africa                            645.7486    170.087      3.797      0.000     312.076     979.421
# aged_70_older                     175.7850     30.621      5.741      0.000     115.713     235.857
# hospital_beds_per_thousand        -81.8990     27.411     -2.988      0.003    -135.674     -28.124
# diabetes_prevalence                32.5064     14.119      2.302      0.021       4.807      60.205
# human_development_index          3102.2510    879.187      3.529      0.000    1377.481    4827.021
# total_boosters_per_hundred         21.7974      3.635      5.996      0.000      14.666      28.928
# new_tests_smoothed_per_thousand    30.0453      4.149      7.242      0.000      21.907      38.184
# positive_rate                    2776.0455    364.835      7.609      0.000    2060.320    3491.771
# ==============================================================================
# Omnibus:                     2043.982   Durbin-Watson:                   1.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1483451.048
# Skew:                           9.069   Prob(JB):                         0.00
# Kurtosis:                     166.039   Cond. No.                     2.41e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 2314571.5705120093
# Removed ft:  Europe
# Ft in use: ['life_expectancy', 'tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.334
# Model:                               OLS   Adj. R-squared:                  0.327
# Method:                    Least Squares   F-statistic:                     50.49
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          7.97e-106
# Time:                           22:56:34   Log-Likelihood:                -11573.
# No. Observations:                   1323   AIC:                         2.317e+04
# Df Residuals:                       1309   BIC:                         2.325e+04
# Df Model:                             13
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1504.7691    388.600     -3.872      0.000   -2267.115    -742.423
# tests_per_case                     -0.0066      0.004     -1.611      0.107      -0.015       0.001
# population_density                 -0.1212      0.057     -2.121      0.034      -0.233      -0.009
# Oceania                          -605.5081    234.778     -2.579      0.010   -1066.091    -144.925
# South America                    -559.1897    186.126     -3.004      0.003    -924.327    -194.052
# median_age                        -50.0325     18.700     -2.676      0.008     -86.717     -13.348
# Africa                            712.6357    165.157      4.315      0.000     388.634    1036.638
# aged_70_older                     170.8852     30.492      5.604      0.000     111.066     230.704
# hospital_beds_per_thousand        -70.2415     26.477     -2.653      0.008    -122.183     -18.300
# diabetes_prevalence                29.6739     14.021      2.116      0.034       2.168      57.179
# human_development_index          2325.0722    738.852      3.147      0.002     875.608    3774.536
# total_boosters_per_hundred         21.2399      3.621      5.866      0.000      14.136      28.344
# new_tests_smoothed_per_thousand    30.4201      4.145      7.339      0.000      22.289      38.551
# positive_rate                    2756.8464    364.874      7.556      0.000    2041.044    3472.649
# ==============================================================================
# Omnibus:                     2027.999   Durbin-Watson:                   1.408
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1415791.867
# Skew:                           8.937   Prob(JB):                         0.00
# Kurtosis:                     162.260   Cond. No.                     1.93e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 2319264.4290173943
# Removed ft:  life_expectancy
# Ft in use: ['tests_per_case', 'population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# ********************
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     new_cases_per_million   R-squared:                       0.333
# Model:                               OLS   Adj. R-squared:                  0.327
# Method:                    Least Squares   F-statistic:                     54.42
# Date:                   Sat, 04 Jun 2022   Prob (F-statistic):          3.78e-106
# Time:                           22:56:34   Log-Likelihood:                -11574.
# No. Observations:                   1323   AIC:                         2.317e+04
# Df Residuals:                       1310   BIC:                         2.324e+04
# Df Model:                             12
# Covariance Type:               nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1488.6599    388.707     -3.830      0.000   -2251.217    -726.103
# population_density                 -0.1170      0.057     -2.049      0.041      -0.229      -0.005
# Oceania                          -614.5154    234.855     -2.617      0.009   -1075.248    -153.783
# South America                    -557.5698    186.236     -2.994      0.003    -922.924    -192.216
# median_age                        -55.6369     18.384     -3.026      0.003     -91.703     -19.571
# Africa                            706.7461    165.217      4.278      0.000     382.627    1030.866
# aged_70_older                     178.9975     30.092      5.948      0.000     119.964     238.031
# hospital_beds_per_thousand        -71.8441     26.474     -2.714      0.007    -123.781     -19.908
# diabetes_prevalence                30.3135     14.024      2.162      0.031       2.802      57.825
# human_development_index          2485.1262    732.588      3.392      0.001    1047.952    3922.300
# total_boosters_per_hundred         20.9087      3.618      5.780      0.000      13.812      28.005
# new_tests_smoothed_per_thousand    30.1998      4.145      7.286      0.000      22.068      38.331
# positive_rate                    2738.9064    364.926      7.505      0.000    2023.002    3454.811
# ==============================================================================
# Omnibus:                     2025.024   Durbin-Watson:                   1.406
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1403751.783
# Skew:                           8.912   Prob(JB):                         0.00
# Kurtosis:                     161.579   Cond. No.                     1.51e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MSE: 2323862.9987269025
# Removed ft:  tests_per_case
# Ft in use: ['population_density', 'Oceania', 'South America', 'median_age', 'Africa', 'aged_70_older', 'hospital_beds_per_thousand', 'diabetes_prevalence', 'human_development_index', 'total_boosters_per_hundred', 'new_tests_smoothed_per_thousand', 'positive_rate']
# Break due to stopping rule: max pvalue = 0.04069836111273681 < 0.05
